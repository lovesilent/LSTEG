# %%
#connect my drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#go to the workplace
# %cd drive/MyDrive/Colab\ Notebooks
# %ls
# Out:
# /content/drive/MyDrive/Colab Notebooks
# DATA/  working_p1/

# %%
# find the dataset (i.e.,facebook)
# %cd DATA/EGO_TWITTER/
# Out:
# /content/drive/MyDrive/Colab Notebooks/DATA/EGO_TWITTER

# %%
#save dataset to dic
a_dic={}
with open('twitter_combined.txt', 'rt') as f:
  for line in f:
    key,value = line.split()
    if key not in a_dic:
      a_dic[key] = value
    else:
      a_dic[key] = a_dic[key]+' '+value
    if value not in a_dic:
      a_dic[value] = key
    else:
      a_dic[value] = a_dic[value]+' '+key

f.close()

# %%
print(a_dic)

# %%
# find the codes 
# %cd ../../working_p1/
# Out:
# /content/drive/My Drive/Colab Notebooks/working_p1

# %%
import p1game as pg
import numpy as np
import imp
import matplotlib.pylab as plt
from IPython import display
from copy import deepcopy

# %%
imp.reload(pg)
# Out:
# <module 'p1game' from '/content/drive/My Drive/Colab Notebooks/working_p1/p1game.py'>

# %%
results={}

# %%
newgame = pg.GameB(a_dic,{'la':1,'si':1,'wo':0.001,'a':3,'b':3,'cn':5},[0.33,0.4,0.27],None)
# Out:
# 81306

# %%
temp_fdic = deepcopy(newgame.fdic)

# %%
newgame = pg.GameB(a_dic,{'la':1,'si':1,'wo':0.001,'a':3,'b':3,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s1=']=result
# Out:
# 26.130035048047247
# [1 5 7 8 4]
# [-1. -5. -7. -8. -4.]

# %%
newgame = pg.GameB(a_dic,{'la':1.2,'si':0.7,'wo':0.001,'a':3,'b':3,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s1>']=result
# Out:
# 29.918968138924683
# [7 9 2 5 7]
# [0.40879569 0.52559446 0.11679877 0.29199692 0.40879569]

# %%
newgame = pg.GameB(a_dic,{'la':0.7,'si':1.2,'wo':0.001,'a':3,'b':3,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s1<']=result
# Out:
# 26.81217131050363
# [5 6 2 9 5]
# [-0.63922377 -0.76706853 -0.25568951 -1.15060279 -0.63922377]

# %%
newgame = pg.GameB(a_dic,{'la':1,'si':1,'wo':0.001,'a':3,'b':5,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s2=']=result
# Out:
# 9.097720050197886
# [5 9 3 3 4]
# [-1.48795815 -2.67832467 -0.89277489 -0.89277489 -1.19036652]

# %%
newgame = pg.GameB(a_dic,{'la':1.2,'si':0.7,'wo':0.001,'a':3,'b':5,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s2>']=result
# Out:
# 11.123006922632179
# [5 3 7 2 7]
# [-0.90420287 -0.54252172 -1.26588402 -0.36168115 -1.26588402]

# %%
newgame = pg.GameB(a_dic,{'la':0.7,'si':1.2,'wo':0.001,'a':3,'b':5,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s2<']=result
# Out:
# 14.498944696249858
# [7 4 9 3 7]
# [-2.29140897 -1.30937655 -2.94609724 -0.98203241 -2.29140897]

# %%
newgame = pg.GameB(a_dic,{'la':1,'si':1,'wo':0.001,'a':3,'b':7,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s3=']=result
# Out:
# -3.638947503350245
# [1 8 6 4 3]
# [-1. -8. -6. -4. -3.]

# %%
newgame = pg.GameB(a_dic,{'la':1.2,'si':0.7,'wo':0.001,'a':3,'b':7,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s3>']=result
# Out:
# 1.5367477982229971
# [9 6 9 1 2]
# [-1.67586426 -1.11724284 -1.67586426 -0.18620714 -0.37241428]

# %%
newgame = pg.GameB(a_dic,{'la':0.7,'si':1.2,'wo':0.001,'a':3,'b':7,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s3<']=result
# Out:
# 0.8760865765130603
# [3 5 2 8 9]
# [-1.8057731  -3.00962183 -1.20384873 -4.81539493 -5.4173193 ]

# %%
newgame = pg.GameB(a_dic,{'la':1,'si':1,'wo':0.001,'a':5,'b':3,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s4=']=result
# Out:
# 13.820288347829567
# [2 1 7 7 9]
# [-1.12729259 -0.5636463  -3.94552407 -3.94552407 -5.07281666]

# %%
newgame = pg.GameB(a_dic,{'la':1.2,'si':0.7,'wo':0.001,'a':5,'b':3,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s4>']=result
# Out:
# 8.62993184775761
# [3 1 7 4 7]
# [-0.55646882 -0.18548961 -1.29842726 -0.74195843 -1.29842726]

# %%
newgame = pg.GameB(a_dic,{'la':0.7,'si':1.2,'wo':0.001,'a':5,'b':3,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s4<']=result
# Out:
# 15.615969242487076
# [6 8 4 8 1]
# [0.45435269 0.60580358 0.30290179 0.60580358 0.07572545]

# %%
newgame = pg.GameB(a_dic,{'la':1,'si':1,'wo':0.001,'a':5,'b':5,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s5=']=result
# Out:
# 17.869791862400604
# [7 3 8 9 9]
# [-0.75343122 -0.32289909 -0.86106425 -0.96869728 -0.96869728]

# %%
newgame = pg.GameB(a_dic,{'la':1.2,'si':0.7,'wo':0.001,'a':5,'b':5,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s5>']=result
# Out:
# -5.75096419620624
# [1 4 3 3 3]
# [-1. -4. -3. -3. -3.]

# %%
newgame = pg.GameB(a_dic,{'la':0.7,'si':1.2,'wo':0.001,'a':5,'b':5,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s5<']=result
# Out:
# 8.297025049761231
# [8 2 6 5 7]
# [0.75394537 0.18848634 0.56545903 0.47121586 0.6597022 ]

# %%
newgame = pg.GameB(a_dic,{'la':1,'si':1,'wo':0.001,'a':5,'b':7,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s6=']=result
# Out:
# -13.188188298760842
# [6 6 2 6 1]
# [-0.53346083 -0.53346083 -0.17782028 -0.53346083 -0.08891014]

# %%
newgame = pg.GameB(a_dic,{'la':1.2,'si':0.7,'wo':0.001,'a':5,'b':7,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s6>']=result
# Out:
# -8.068342522479824
# [1 5 7 8 5]
# [-1. -5. -7. -8. -5.]

# %%
newgame = pg.GameB(a_dic,{'la':0.7,'si':1.2,'wo':0.001,'a':5,'b':7,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s6<']=result
# Out:
# -11.816981680251793
# [5 3 5 5 5]
# [-1.34885294 -0.80931176 -1.34885294 -1.34885294 -1.34885294]

# %%
newgame = pg.GameB(a_dic,{'la':1,'si':1,'wo':0.001,'a':7,'b':3,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s7=']=result
# Out:
# -13.477823174875496
# [1 2 2 2 3]
# [-1. -2. -2. -2. -3.]

# %%
newgame = pg.GameB(a_dic,{'la':1.2,'si':0.7,'wo':0.001,'a':7,'b':3,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s7>']=result
# Out:
# 2.865703939100733
# [2 3 4 9 9]
# [-1.16042557 -1.74063835 -2.32085113 -5.22191505 -5.22191505]

# %%
newgame = pg.GameB(a_dic,{'la':0.7,'si':1.2,'wo':0.001,'a':7,'b':3,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s7<']=result
# Out:
# 3.4889795889093165
# [1 9 5 8 3]
# [-1. -9. -5. -8. -3.]

# %%
newgame = pg.GameB(a_dic,{'la':1,'si':1,'wo':0.001,'a':7,'b':5,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s8=']=result
# Out:
# 3.6028487687235753
# [7 7 8 3 9]
# [-0.33480884 -0.33480884 -0.38263868 -0.1434895  -0.43046851]

# %%
newgame = pg.GameB(a_dic,{'la':1.2,'si':0.7,'wo':0.001,'a':7,'b':5,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s8>']=result
# Out:
# -9.706699768932353
# [5 2 3 6 6]
# [0.94146852 0.37658741 0.56488111 1.12976222 1.12976222]

# %%
newgame = pg.GameB(a_dic,{'la':0.7,'si':1.2,'wo':0.001,'a':7,'b':5,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s8<']=result
# Out:
# -8.591452874971722
# [5 2 6 5 2]
# [1.88704362 0.75481745 2.26445234 1.88704362 0.75481745]

# %%
newgame = pg.GameB(a_dic,{'la':1,'si':1,'wo':0.001,'a':7,'b':7,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s9=']=result
# Out:
# -14.887053886744582
# [4 7 9 1 2]
# [-0.09797849 -0.17146236 -0.2204516  -0.02449462 -0.04898925]

# %%
newgame = pg.GameB(a_dic,{'la':1.2,'si':0.7,'wo':0.001,'a':7,'b':7,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s9>']=result
# Out:
# -27.38169835917101
# [2 1 1 3 5]
# [-0.12045577 -0.06022788 -0.06022788 -0.18068365 -0.30113942]

# %%
newgame = pg.GameB(a_dic,{'la':0.7,'si':1.2,'wo':0.001,'a':7,'b':7,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s9<']=result
# Out:
# -16.48203776115053
# [4 7 2 2 7]
# [-0.07774543 -0.1360545  -0.03887272 -0.03887272 -0.1360545 ]

# %%
if all (k in results for k in ('s1=','s1>','s1<','s2=','s2>','s2<','s3=','s3>','s3<','s4=','s4>','s4<','s5=','s5>','s5<','s6=','s6>','s6<','s7=','s7>','s7<','s8=','s8>','s8<','s9=','s9>','s9<')):
  print("ok")
# Out:
# ok

# %%
#save results
outfile = 'bresult_t.npz'
np.savez(outfile, **results)

# %%
npzfile = np.load(outfile)
print('npzfile.files: {}'.format(npzfile.files))
print('npzfile["s9>"]: {}'.format(npzfile["s6>"]))
