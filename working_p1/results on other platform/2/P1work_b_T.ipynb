# %%
#connect my drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#go to the workplace
# %cd drive/MyDrive/Colab\ Notebooks
# %ls
# Out:
# /content/drive/MyDrive/Colab Notebooks
# DATA/  tutorial/  working_p1/  working_p2/  working_results/

# %%
# find the dataset (i.e.,twitter)
# %cd DATA/EGO_TWITTER/
# Out:
# /content/drive/MyDrive/Colab Notebooks/DATA/EGO_TWITTER

# %%
#save dataset to dic
a_dic={}
with open('twitter_combined.txt', 'rt') as f:
  for line in f:
    key,value = line.split()
    if key not in a_dic:
      a_dic[key] = value
    else:
      a_dic[key] = a_dic[key]+' '+value
    if value not in a_dic:
      a_dic[value] = key
    else:
      a_dic[value] = a_dic[value]+' '+key

f.close()

# %%
print(a_dic)

# %%
# find the codes 
# %cd ../../working_p1/results\ on\ other\ platform
# %cd 2
# Out:
# /content/drive/My Drive/Colab Notebooks/working_p1/results on other platform
# /content/drive/My Drive/Colab Notebooks/working_p1/results on other platform/2

# %%
import exp as pg
import numpy as np
import imp
import matplotlib.pylab as plt
from IPython import display
from copy import deepcopy

# %%
imp.reload(pg)
# Out:
# <module 'exp' from '/content/drive/My Drive/Colab Notebooks/working_p1/results on other platform/2/exp.py'>

# %%
tempresult={}  #[0.4,0.4,0.2]    [0.38,0.35,0.27]     [0.33,0.4,0.27]

# %%
newgame = pg.GameFinal(a_dic,{'la':1,'si':1,'wo':0.001},[0.38,0.35,0.27],None)
# Out:
# 81306

# %%
temp_fdic = deepcopy(newgame.fdic)

# %%
newgame = pg.GameFinal(a_dic,{'la':1,'si':1,'wo':0.001},[0.4,0.4,0.2],temp_fdic)
y, result = newgame.run_time(100)
plt.plot(y,':')
tempresult['a1']=result
# Out:
# 81306
# Loading...: 100%|██████████| 100/100 [36:41<00:00, 22.02s/it]

# %%
newgame = pg.GameFinal(a_dic,{'la':1,'si':1,'wo':0.001},[0.38,0.35,0.27],temp_fdic)
y, result = newgame.run_time(100)
plt.plot(y,':')
tempresult['a2']=result
# Out:
# 81306
# Loading...: 100%|██████████| 100/100 [37:41<00:00, 22.61s/it]

# %%
newgame = pg.GameFinal(a_dic,{'la':1,'si':1,'wo':0.001},[0.33,0.4,0.27],temp_fdic)
y, result = newgame.run_time(100)
plt.plot(y,':')
tempresult['a3']=result
# Out:
# 81306
# Loading...: 100%|██████████| 100/100 [37:11<00:00, 22.31s/it]

# %%
import pandas as pd

# %%
writer = pd.ExcelWriter('b.xlsx')

# %%
dtr = pd.DataFrame(tempresult['a1'])
dtr.to_excel(writer,'page_1',float_format='%.5f')
writer.save()

# %%
dtr = pd.DataFrame(tempresult['a2'])
dtr.to_excel(writer,'page_2',float_format='%.5f')
writer.save()

# %%
dtr = pd.DataFrame(tempresult['a3'])
dtr.to_excel(writer,'page_3',float_format='%.5f')
writer.save()

# %%
writer.close()

# %%
results={}

# %%
newgame = pg.GameB(a_dic,{'la':1,'si':1,'wo':0.001,'a':3,'b':3,'cn':5},[0.33,0.4,0.27],None)

# %%
temp_fdic = deepcopy(newgame.fdic)

# %%
newgame = pg.GameB(a_dic,{'la':1,'si':1,'wo':0.001,'a':3,'b':3,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s1=']=result
# Out:
# 27.32123960227409
# [5 9 4 2 6]
# [5.53488137 9.96278647 4.4279051  2.21395255 6.64185765]

# %%
newgame = pg.GameB(a_dic,{'la':1.2,'si':0.7,'wo':0.001,'a':3,'b':3,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s1>']=result
# Out:
# 35.29385635431025
# [5 9 9 4 8]
# [3.0422376  5.47602768 5.47602768 2.43379008 4.86758016]

# %%
newgame = pg.GameB(a_dic,{'la':0.7,'si':1.2,'wo':0.001,'a':3,'b':3,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s1<']=result
# Out:
# 20.451512463463594
# [7 4 4 3 3]
# [9.20582427 5.26047101 5.26047101 3.94535326 3.94535326]

# %%
newgame = pg.GameB(a_dic,{'la':1,'si':1,'wo':0.001,'a':3,'b':5,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s2=']=result
# Out:
# 7.732077969840063
# [1 8 4 2 8]
# [0.51077728 4.08621827 2.04310913 1.02155457 4.08621827]

# %%
newgame = pg.GameB(a_dic,{'la':1.2,'si':0.7,'wo':0.001,'a':3,'b':5,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s2>']=result
# Out:
# 14.037154899932084
# [6 8 2 6 3]
# [5.35121744 7.13495659 1.78373915 5.35121744 2.67560872]

# %%
newgame = pg.GameB(a_dic,{'la':0.7,'si':1.2,'wo':0.001,'a':3,'b':5,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s2<']=result
# Out:
# 8.510149181274514
# [3 4 1 8 8]
# [1.40232544 1.86976725 0.46744181 3.7395345  3.7395345 ]

# %%
newgame = pg.GameB(a_dic,{'la':1,'si':1,'wo':0.001,'a':3,'b':7,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s3=']=result
# Out:
# -2.843465499851547
# [7 5 1 4 4]
# [6.27840929 4.48457807 0.89691561 3.58766245 3.58766245]

# %%
newgame = pg.GameB(a_dic,{'la':1.2,'si':0.7,'wo':0.001,'a':3,'b':7,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s3>']=result
# Out:
# 2.8106504977413707
# [7 3 9 8 1]
# [1.62489476 0.69638347 2.08915041 1.85702259 0.23212782]

# %%
newgame = pg.GameB(a_dic,{'la':0.7,'si':1.2,'wo':0.001,'a':3,'b':7,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s3<']=result
# Out:
# -2.3722440904343216
# [1 4 9 5 5]
# [0.37696781 1.50787125 3.39271031 1.88483906 1.88483906]

# %%
newgame = pg.GameB(a_dic,{'la':1,'si':1,'wo':0.001,'a':5,'b':3,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s4=']=result
# Out:
# 2.92225318049276
# [1 4 2 6 2]
# [ 3.28055374 13.12221495  6.56110748 19.68332243  6.56110748]

# %%
newgame = pg.GameB(a_dic,{'la':1.2,'si':0.7,'wo':0.001,'a':5,'b':3,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s4>']=result
# Out:
# 16.136092682718946
# [1 8 9 7 4]
# [ 1.23567977  9.88543815 11.12111792  8.64975838  4.94271908]

# %%
newgame = pg.GameB(a_dic,{'la':0.7,'si':1.2,'wo':0.001,'a':5,'b':3,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s4<']=result
# Out:
# 19.06883932518103
# [8 7 4 9 1]
# [10.33724405  9.04508854  5.16862202 11.62939955  1.29215551]

# %%
newgame = pg.GameB(a_dic,{'la':1,'si':1,'wo':0.001,'a':5,'b':5,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s5=']=result
# Out:
# -0.2860664447898955
# [4 2 5 4 3]
# [10.25753717  5.12876859 12.82192147 10.25753717  7.69315288]

# %%
newgame = pg.GameB(a_dic,{'la':1.2,'si':0.7,'wo':0.001,'a':5,'b':5,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s5>']=result
# Out:
# 8.031049075375627
# [3 6 7 2 9]
# [ 4.16348203  8.32696405  9.71479139  2.77565468 12.49044608]

# %%
newgame = pg.GameB(a_dic,{'la':0.7,'si':1.2,'wo':0.001,'a':5,'b':5,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s5<']=result
# Out:
# 10.313760852908047
# [9 5 7 2 7]
# [8.31633612 4.62018673 6.46826143 1.84807469 6.46826143]

# %%
newgame = pg.GameB(a_dic,{'la':1,'si':1,'wo':0.001,'a':5,'b':7,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s6=']=result
# Out:
# -4.531068246449195
# [8 5 5 4 7]
# [4.14938862 2.59336789 2.59336789 2.07469431 3.63071504]

# %%
newgame = pg.GameB(a_dic,{'la':1.2,'si':0.7,'wo':0.001,'a':5,'b':7,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s6>']=result
# Out:
# 2.457848025841656
# [9 7 4 9 7]
# [1.95365359 1.51950835 0.86829049 1.95365359 1.51950835]

# %%
newgame = pg.GameB(a_dic,{'la':0.7,'si':1.2,'wo':0.001,'a':5,'b':7,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s6<']=result
# Out:
# -7.943090270904186
# [3 9 3 4 8]
# [1.51834469 4.55503408 1.51834469 2.02445959 4.04891918]

# %%
newgame = pg.GameB(a_dic,{'la':1,'si':1,'wo':0.001,'a':7,'b':3,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s7=']=result
# Out:
# 8.236035401810796
# [8 3 9 4 7]
# [10.03504125  3.76314047 11.28942141  5.01752063  8.78066109]

# %%
newgame = pg.GameB(a_dic,{'la':1.2,'si':0.7,'wo':0.001,'a':7,'b':3,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s7>']=result
# Out:
# 4.827620853320795
# [1 9 8 4 7]
# [ 1.38934818 12.50413362 11.11478544  5.55739272  9.72543726]

# %%
newgame = pg.GameB(a_dic,{'la':0.7,'si':1.2,'wo':0.001,'a':7,'b':3,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s7<']=result
# Out:
# -0.01784778012071797
# [2 4 7 1 8]
# [ 4.34678012  8.69356025 15.21373043  2.17339006 17.38712049]

# %%
newgame = pg.GameB(a_dic,{'la':1,'si':1,'wo':0.001,'a':7,'b':5,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s8=']=result
# Out:
# -0.7099847549635996
# [5 9 9 5 2]
# [ 6.61843899 11.91319018 11.91319018  6.61843899  2.6473756 ]

# %%
newgame = pg.GameB(a_dic,{'la':1.2,'si':0.7,'wo':0.001,'a':7,'b':5,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s8>']=result

# %%
newgame = pg.GameB(a_dic,{'la':0.7,'si':1.2,'wo':0.001,'a':7,'b':5,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s8<']=result

# %%
newgame = pg.GameB(a_dic,{'la':1,'si':1,'wo':0.001,'a':7,'b':7,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s9=']=result

# %%
newgame = pg.GameB(a_dic,{'la':1.2,'si':0.7,'wo':0.001,'a':7,'b':7,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s9>']=result

# %%
newgame = pg.GameB(a_dic,{'la':0.7,'si':1.2,'wo':0.001,'a':7,'b':7,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/81306]
result = newgame.pd[1]/81306
for i in range(60): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  result = np.vstack((result,newgame.pd[1]/81306))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s9<']=result

# %%
if all (k in results for k in ('s1=','s1>','s1<','s2=','s2>','s2<','s3=','s3>','s3<','s4=','s4>','s4<','s5=','s5>','s5<','s6=','s6>','s6<','s7=','s7>','s7<','s8=','s8>','s8<','s9=','s9>','s9<')):
  print("ok")

# %%
#save results
outfile = 'bresult_t.npz'
np.savez(outfile, **results)

# %%
npzfile = np.load(outfile)
print('npzfile.files: {}'.format(npzfile.files))
print('npzfile["s9>"]: {}'.format(npzfile["s6>"]))

# %%
import numpy as np
print('npzfile["std"]: {}'.format([0.29345928, 0.41725088, 0.28928984]))
npzfile = np.load('bresult_t.npz')
print('\n')
print('npzfile["s1="]: {}'.format(npzfile["s1="][-1]))
print('npzfile["s1>"]: {}'.format(npzfile["s1>"][-1]))
print('npzfile["s1<"]: {}'.format(npzfile["s1<"][-1]))
print('\n')
print('npzfile["s2="]: {}'.format(npzfile["s2="][-1]))
print('npzfile["s2>"]: {}'.format(npzfile["s2>"][-1]))
print('npzfile["s2<"]: {}'.format(npzfile["s2<"][-1]))
print('\n')
print('\n')
print('npzfile["s3="]: {}'.format(npzfile["s3="][-1]))
print('npzfile["s3>"]: {}'.format(npzfile["s3>"][-1]))
print('npzfile["s3<"]: {}'.format(npzfile["s3<"][-1]))
print('\n')
print('npzfile["s4="]: {}'.format(npzfile["s4="][-1]))
print('npzfile["s4>"]: {}'.format(npzfile["s4>"][-1]))
print('npzfile["s4<"]: {}'.format(npzfile["s4<"][-1]))
print('\n')
print('npzfile["s5="]: {}'.format(npzfile["s5="][-1]))
print('npzfile["s5>"]: {}'.format(npzfile["s5>"][-1]))
print('npzfile["s5<"]: {}'.format(npzfile["s5<"][-1]))
print('\n')
print('npzfile["s6="]: {}'.format(npzfile["s6="][-1]))
print('npzfile["s6>"]: {}'.format(npzfile["s6>"][-1]))
print('npzfile["s6<"]: {}'.format(npzfile["s6<"][-1]))
print('\n')
print('npzfile["s7="]: {}'.format(npzfile["s7="][-1]))
print('npzfile["s7>"]: {}'.format(npzfile["s7>"][-1]))
print('npzfile["s7<"]: {}'.format(npzfile["s7<"][-1]))
print('\n')
print('npzfile["s8="]: {}'.format(npzfile["s8="][-1]))
print('npzfile["s8>"]: {}'.format(npzfile["s8>"][-1]))
print('npzfile["s8<"]: {}'.format(npzfile["s8<"][-1]))
print('\n')
print('npzfile["s9="]: {}'.format(npzfile["s9="][-1]))
print('npzfile["s9>"]: {}'.format(npzfile["s9>"][-1]))
print('npzfile["s9<"]: {}'.format(npzfile["s9<"][-1]))

# %%
import numpy as np
print('npzfile["std"]: {}'.format([0.29345928, 0.41725088, 0.28928984]))
npzfile = np.load('bresult_t.npz')
print('\n')
print('npzfile["s1="]: {}'.format(npzfile["s1="][-1]))
print('npzfile["s2="]: {}'.format(npzfile["s2="][-1]))
print('npzfile["s3="]: {}'.format(npzfile["s3="][-1]))
print('npzfile["s4="]: {}'.format(npzfile["s4="][-1]))
print('npzfile["s5="]: {}'.format(npzfile["s5="][-1]))
print('npzfile["s6="]: {}'.format(npzfile["s6="][-1]))
print('npzfile["s7="]: {}'.format(npzfile["s7="][-1]))
print('npzfile["s8="]: {}'.format(npzfile["s8="][-1]))
print('npzfile["s9="]: {}'.format(npzfile["s9="][-1]))
print('\n')
print('npzfile["s1>"]: {}'.format(npzfile["s1>"][-1]))
print('npzfile["s2>"]: {}'.format(npzfile["s2>"][-1]))
print('npzfile["s3>"]: {}'.format(npzfile["s3>"][-1]))
print('npzfile["s4>"]: {}'.format(npzfile["s4>"][-1]))
print('npzfile["s5>"]: {}'.format(npzfile["s5>"][-1]))
print('npzfile["s6>"]: {}'.format(npzfile["s6>"][-1]))
print('npzfile["s7>"]: {}'.format(npzfile["s7>"][-1]))
print('npzfile["s8>"]: {}'.format(npzfile["s8>"][-1]))
print('npzfile["s9>"]: {}'.format(npzfile["s9>"][-1]))
print('\n')
print('npzfile["s1<"]: {}'.format(npzfile["s1<"][-1]))
print('npzfile["s2<"]: {}'.format(npzfile["s2<"][-1]))
print('npzfile["s3<"]: {}'.format(npzfile["s3<"][-1]))
print('npzfile["s4<"]: {}'.format(npzfile["s4<"][-1]))
print('npzfile["s5<"]: {}'.format(npzfile["s5<"][-1]))
print('npzfile["s6<"]: {}'.format(npzfile["s6<"][-1]))
print('npzfile["s7<"]: {}'.format(npzfile["s7<"][-1]))
print('npzfile["s8<"]: {}'.format(npzfile["s8<"][-1]))
print('npzfile["s9<"]: {}'.format(npzfile["s9<"][-1]))
# Out:
# npzfile["std"]: [0.29345928, 0.41725088, 0.28928984]
#
#
# npzfile["s1="]: [0.20329373 0.25891078 0.53779549]
# npzfile["s2="]: [0.00233685 0.12309055 0.8745726 ]
# npzfile["s3="]: [0.01119229 0.03775859 0.95104912]
# npzfile["s4="]: [0.96411089 0.00404644 0.03184267]
# npzfile["s5="]: [0.32151379 0.12735837 0.55112784]
# npzfile["s6="]: [0.00446462 0.22046343 0.77507195]
# npzfile["s7="]: [0.98693823 0.00412024 0.00894153]
# npzfile["s8="]: [0.88462106 0.00525176 0.11012717]
# npzfile["s9="]: [0.15740536 0.33945834 0.5031363 ]
#
#
# npzfile["s1>"]: [0.65553588 0.01951885 0.32494527]
# npzfile["s2>"]: [0.0407473  0.16152559 0.79772711]
# npzfile["s3>"]: [0.00223846 0.11728532 0.88047623]
# npzfile["s4>"]: [0.98763929 0.00562074 0.00673997]
# npzfile["s5>"]: [0.5250658 0.032925  0.4420092]
# npzfile["s6>"]: [0.00392345 0.28674391 0.70933264]
# npzfile["s7>"]: [0.99516641 0.00281652 0.00201707]
# npzfile["s8>"]: [0.96340983 0.00528866 0.0313015 ]
# ...

# %%
np.random.random(2)/10
# Out:
# array([0.00516179, 0.0818272 ])

# %%
import numpy as np
outfile = 'bresult_t.npz'
npzfile = np.load(outfile)

# %%
import pandas as pd
writer = pd.ExcelWriter('d.xlsx')

# %%
dtr = pd.DataFrame(npzfile['s5>'])
dtr.to_excel(writer,'page_1',float_format='%.5f')
writer.save()

# %%
dtr = pd.DataFrame(npzfile['s5<'])
dtr.to_excel(writer,'page_2',float_format='%.5f')
writer.save()

# %%
writer.close()

# %%
tempresuls={}

# %%
newgame = pg.GameFinal(a_dic,{'la':1.2,'si':0.7,'wo':0.001},[0.52507,0.03292,0.44201],temp_fdic)
y, result = newgame.run_time(40)
plt.plot(y,':')
tempresult['b1']=result
# Out:
# 81306
# Loading...: 100%|██████████| 40/40 [14:53<00:00, 22.34s/it]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-6aeb08da28d2> in <module>()
#       2 y, result = newgame.run_time(40)
#       3 plt.plot(y,':')
# ----> 4 tempresult['b1']=result
#
# NameError: name 'tempresult' is not defined

# %%
tempresuls['b1']=result

# %%
newgame = pg.GameFinal(a_dic,{'la':0.7,'si':1.2,'wo':0.001},[0.06544,0.30801,0.62655],temp_fdic)
y, result2 = newgame.run_time(40)
plt.plot(y,':')
tempresuls['b2']=result2
# Out:
# 81306
# Loading...: 100%|██████████| 40/40 [15:53<00:00, 23.85s/it]

# %%
writer = pd.ExcelWriter('d+.xlsx')
dtr = pd.DataFrame(tempresuls['b1'])
dtr.to_excel(writer,'page_1',float_format='%.5f')
writer.save()
dtr = pd.DataFrame(tempresuls['b2'])
dtr.to_excel(writer,'page_2',float_format='%.5f')
writer.save()
writer.close()
