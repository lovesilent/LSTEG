# %%
#connect my drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#go to the workplace
# %cd drive/MyDrive/Colab\ Notebooks
# %ls
# Out:
# /content/drive/MyDrive/Colab Notebooks
# DATA/  tutorial/  working_p1/  working_p2/  working_results/

# %%
# find the dataset (i.e.,facebook)
# %cd DATA/EGO_FACEBOOK/
# Out:
# /content/drive/MyDrive/Colab Notebooks/DATA/EGO_FACEBOOK

# %%
#save dataset to dic
a_dic={}
with open('facebook_combined.txt', 'rt') as f:
  for line in f:
    key,value = line.split()
    if key not in a_dic:
      a_dic[key] = value
    else:
      a_dic[key] = a_dic[key]+' '+value
    if value not in a_dic:
      a_dic[value] = key
    else:
      a_dic[value] = a_dic[value]+' '+key

f.close()

# %%
print(a_dic)

# %%
# find the codes 
# %cd ../../working_p1/results\ on\ other\ platform
# %cd 2
# Out:
# /content/drive/MyDrive/Colab Notebooks/working_p1/results on other platform
# /content/drive/MyDrive/Colab Notebooks/working_p1/results on other platform/2

# %%
import exp as pg
import numpy as np
import imp
import matplotlib.pylab as plt
from IPython import display
from copy import deepcopy

# %%
imp.reload(pg)
# Out:
# <module 'exp' from '/content/drive/My Drive/Colab Notebooks/working_p1/results on other platform/2/exp.py'>

# %%
tempresult={}  #[0.4,0.4,0.2]    [0.38,0.35,0.27]     [0.33,0.4,0.27]

# %%
newgame = pg.GameFinal(a_dic,{'la':1,'si':1,'wo':0.001},[0.38,0.35,0.27],None)
# Out:
# 4039

# %%
temp_fdic = deepcopy(newgame.fdic)

# %%
newgame = pg.GameFinal(a_dic,{'la':1,'si':1,'wo':0.001},[0.4,0.4,0.2],temp_fdic)
y, result = newgame.run_time(100)
plt.plot(y,':')
tempresult['a1']=result
# Out:
# 4039
# Loading...: 100%|██████████| 100/100 [01:31<00:00,  1.10it/s]

# %%
newgame = pg.GameFinal(a_dic,{'la':1,'si':1,'wo':0.001},[0.38,0.35,0.27],temp_fdic)
y, result = newgame.run_time(100)
plt.plot(y,':')
tempresult['a2']=result
# Out:
# 4039
# Loading...: 100%|██████████| 100/100 [01:30<00:00,  1.10it/s]

# %%
newgame = pg.GameFinal(a_dic,{'la':1,'si':1,'wo':0.001},[0.33,0.4,0.27],temp_fdic)
y, result = newgame.run_time(100)
plt.plot(y,':')
tempresult['a3']=result
# Out:
# 4039
# Loading...: 100%|██████████| 100/100 [01:30<00:00,  1.11it/s]

# %%
tempresult['a1']

# %%
import pandas as pd

# %%
writer = pd.ExcelWriter('a.xlsx')

# %%
dtr = pd.DataFrame(tempresult['a1'])
dtr.to_excel(writer,'page_1',float_format='%.5f')
writer.save()

# %%
dtr = pd.DataFrame(tempresult['a2'])
dtr.to_excel(writer,'page_2',float_format='%.5f')
writer.save()

# %%
dtr = pd.DataFrame(tempresult['a3'])
dtr.to_excel(writer,'page_3',float_format='%.5f')
writer.save()

# %%
writer.close()

# %%
results={}

# %%
newgame = pg.GameB(a_dic,{'la':1,'si':1,'wo':0.001,'a':3,'b':3,'cn':5},[0.33,0.4,0.27],None)

# %%
temp_fdic = deepcopy(newgame.fdic)

# %%
newgame = pg.GameB(a_dic,{'la':1,'si':1,'wo':0.001,'a':3,'b':3,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/4039]
result = newgame.pd[1]/4039
for i in range(100): 
  newgame.run_slot()
  y.append(newgame.pd[1]/4039)
  result = np.vstack((result,newgame.pd[1]/4039))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s1=']=result
# Out:
# 33.688170412815566
# [6 7 8 6 7]
# [0.54834456 0.63973532 0.73112608 0.54834456 0.63973532]

# %%
newgame = pg.GameB(a_dic,{'la':1.2,'si':0.7,'wo':0.001,'a':3,'b':3,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/4039]
result = newgame.pd[1]/4039
for i in range(100): 
  newgame.run_slot()
  y.append(newgame.pd[1]/4039)
  result = np.vstack((result,newgame.pd[1]/4039))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s1>']=result
# Out:
# 21.611624701761727
# [5 3 2 3 8]
# [4.89144758 2.93486855 1.95657903 2.93486855 7.82631612]

# %%
newgame = pg.GameB(a_dic,{'la':0.7,'si':1.2,'wo':0.001,'a':3,'b':3,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/4039]
result = newgame.pd[1]/4039
for i in range(100): 
  newgame.run_slot()
  y.append(newgame.pd[1]/4039)
  result = np.vstack((result,newgame.pd[1]/4039))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s1<']=result
# Out:
# 24.51226961609207
# [9 5 1 2 8]
# [4.64598086 2.58110048 0.5162201  1.03244019 4.12976077]

# %%
newgame = pg.GameB(a_dic,{'la':1,'si':1,'wo':0.001,'a':3,'b':5,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/4039]
result = newgame.pd[1]/4039
for i in range(100): 
  newgame.run_slot()
  y.append(newgame.pd[1]/4039)
  result = np.vstack((result,newgame.pd[1]/4039))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s2=']=result
# Out:
# -5.183373677326628
# [5 4 1 1 1]
# [0.70281329 0.56225063 0.14056266 0.14056266 0.14056266]

# %%
newgame = pg.GameB(a_dic,{'la':1.2,'si':0.7,'wo':0.001,'a':3,'b':5,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/4039]
result = newgame.pd[1]/4039
for i in range(100): 
  newgame.run_slot()
  y.append(newgame.pd[1]/4039)
  result = np.vstack((result,newgame.pd[1]/4039))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s2>']=result
# Out:
# 12.02962644666728
# [2 8 5 9 6]
# [-1.22275955 -4.89103819 -3.05689887 -5.50241797 -3.66827864]

# %%
newgame = pg.GameB(a_dic,{'la':0.7,'si':1.2,'wo':0.001,'a':3,'b':5,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/4039]
result = newgame.pd[1]/4039
for i in range(100): 
  newgame.run_slot()
  y.append(newgame.pd[1]/4039)
  result = np.vstack((result,newgame.pd[1]/4039))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s2<']=result
# Out:
# 5.52039941645787
# [1 8 6 1 6]
# [-0.31558179 -2.52465433 -1.89349074 -0.31558179 -1.89349074]

# %%
newgame = pg.GameB(a_dic,{'la':1,'si':1,'wo':0.001,'a':3,'b':7,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/4039]
result = newgame.pd[1]/4039
for i in range(100): 
  newgame.run_slot()
  y.append(newgame.pd[1]/4039)
  result = np.vstack((result,newgame.pd[1]/4039))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s3=']=result
# Out:
# 1.5084356042750713
# [9 3 4 4 7]
# [-5.1074331  -1.7024777  -2.26997027 -2.26997027 -3.97244797]

# %%
newgame = pg.GameB(a_dic,{'la':1.2,'si':0.7,'wo':0.001,'a':3,'b':7,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/4039]
result = newgame.pd[1]/4039
for i in range(100): 
  newgame.run_slot()
  y.append(newgame.pd[1]/4039)
  result = np.vstack((result,newgame.pd[1]/4039))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s3>']=result
# Out:
# -9.982718004498416
# [5 3 1 3 3]
# [-0.85662567 -0.5139754  -0.17132513 -0.5139754  -0.5139754 ]

# %%
newgame = pg.GameB(a_dic,{'la':0.7,'si':1.2,'wo':0.001,'a':3,'b':7,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/4039]
result = newgame.pd[1]/4039
for i in range(100): 
  newgame.run_slot()
  y.append(newgame.pd[1]/4039)
  result = np.vstack((result,newgame.pd[1]/4039))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s3<']=result
# Out:
# 10.818712758274415
# [6 9 5 9 6]
# [-3.70412739 -5.55619109 -3.08677283 -5.55619109 -3.70412739]

# %%
newgame = pg.GameB(a_dic,{'la':1,'si':1,'wo':0.001,'a':5,'b':3,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/4039]
result = newgame.pd[1]/4039
for i in range(100): 
  newgame.run_slot()
  y.append(newgame.pd[1]/4039)
  result = np.vstack((result,newgame.pd[1]/4039))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s4=']=result
# Out:
# 14.075508690197083
# [3 1 6 8 8]
# [2.36869794 0.78956598 4.73739588 6.31652784 6.31652784]

# %%
newgame = pg.GameB(a_dic,{'la':1.2,'si':0.7,'wo':0.001,'a':5,'b':3,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/4039]
result = newgame.pd[1]/4039
for i in range(100): 
  newgame.run_slot()
  y.append(newgame.pd[1]/4039)
  result = np.vstack((result,newgame.pd[1]/4039))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s4>']=result
# Out:
# 17.47504212667345
# [2 8 3 9 8]
# [1.02521965 4.10087859 1.53782947 4.61348841 4.10087859]

# %%
newgame = pg.GameB(a_dic,{'la':0.7,'si':1.2,'wo':0.001,'a':5,'b':3,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/4039]
result = newgame.pd[1]/4039
for i in range(100): 
  newgame.run_slot()
  y.append(newgame.pd[1]/4039)
  result = np.vstack((result,newgame.pd[1]/4039))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s4<']=result
# Out:
# 13.601258302380977
# [7 2 6 9 3]
# [4.38192158 1.25197759 3.75593278 5.63389917 1.87796639]

# %%
newgame = pg.GameB(a_dic,{'la':1,'si':1,'wo':0.001,'a':5,'b':5,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/4039]
result = newgame.pd[1]/4039
for i in range(100): 
  newgame.run_slot()
  y.append(newgame.pd[1]/4039)
  result = np.vstack((result,newgame.pd[1]/4039))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s5=']=result
# Out:
# 20.049681674889868
# [8 8 4 5 9]
# [2.87649275 2.87649275 1.43824637 1.79780797 3.23605434]

# %%
newgame = pg.GameB(a_dic,{'la':1.2,'si':0.7,'wo':0.001,'a':5,'b':5,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/4039]
result = newgame.pd[1]/4039
for i in range(100): 
  newgame.run_slot()
  y.append(newgame.pd[1]/4039)
  result = np.vstack((result,newgame.pd[1]/4039))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s5>']=result
# Out:
# 12.67877404023914
# [6 4 1 7 9]
# [4.41195996 2.94130664 0.73532666 5.14728662 6.61793994]

# %%
newgame = pg.GameB(a_dic,{'la':0.7,'si':1.2,'wo':0.001,'a':5,'b':5,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/4039]
result = newgame.pd[1]/4039
for i in range(100): 
  newgame.run_slot()
  y.append(newgame.pd[1]/4039)
  result = np.vstack((result,newgame.pd[1]/4039))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s5<']=result
# Out:
# 3.677175542903221
# [2 3 3 5 5]
# [2.95709978 4.43564968 4.43564968 7.39274946 7.39274946]

# %%
newgame = pg.GameB(a_dic,{'la':1,'si':1,'wo':0.001,'a':5,'b':7,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/4039]
result = newgame.pd[1]/4039
for i in range(100): 
  newgame.run_slot()
  y.append(newgame.pd[1]/4039)
  result = np.vstack((result,newgame.pd[1]/4039))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s6=']=result
# Out:
# -4.8871540728105245
# [6 9 2 6 3]
# [-2.24551129 -3.36826694 -0.74850376 -2.24551129 -1.12275565]

# %%
newgame = pg.GameB(a_dic,{'la':1.2,'si':0.7,'wo':0.001,'a':5,'b':7,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/4039]
result = newgame.pd[1]/4039
for i in range(100): 
  newgame.run_slot()
  y.append(newgame.pd[1]/4039)
  result = np.vstack((result,newgame.pd[1]/4039))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s6>']=result
# Out:
# -10.357361968263774
# [1 3 6 6 4]
# [-0.09639459 -0.28918376 -0.57836753 -0.57836753 -0.38557835]

# %%
newgame = pg.GameB(a_dic,{'la':0.7,'si':1.2,'wo':0.001,'a':5,'b':7,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/4039]
result = newgame.pd[1]/4039
for i in range(100): 
  newgame.run_slot()
  y.append(newgame.pd[1]/4039)
  result = np.vstack((result,newgame.pd[1]/4039))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s6<']=result
# Out:
# -6.7560453428153195
# [9 1 5 9 1]
# [-3.89806879 -0.43311875 -2.16559377 -3.89806879 -0.43311875]

# %%
newgame = pg.GameB(a_dic,{'la':1,'si':1,'wo':0.001,'a':7,'b':3,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/4039]
result = newgame.pd[1]/4039
for i in range(100): 
  newgame.run_slot()
  y.append(newgame.pd[1]/4039)
  result = np.vstack((result,newgame.pd[1]/4039))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s7=']=result
# Out:
# 1.6667496520919372
# [2 4 6 3 7]
# [2.36804233 4.73608465 7.10412698 3.55206349 8.28814814]

# %%
newgame = pg.GameB(a_dic,{'la':1.2,'si':0.7,'wo':0.001,'a':7,'b':3,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/4039]
result = newgame.pd[1]/4039
for i in range(100): 
  newgame.run_slot()
  y.append(newgame.pd[1]/4039)
  result = np.vstack((result,newgame.pd[1]/4039))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s7>']=result
# Out:
# 3.045113289722657
# [3 5 9 5 3]
# [2.66476994 4.44128323 7.99430982 4.44128323 2.66476994]

# %%
newgame = pg.GameB(a_dic,{'la':0.7,'si':1.2,'wo':0.001,'a':7,'b':3,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/4039]
result = newgame.pd[1]/4039
for i in range(100): 
  newgame.run_slot()
  y.append(newgame.pd[1]/4039)
  result = np.vstack((result,newgame.pd[1]/4039))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s7<']=result
# Out:
# -2.119288520730308
# [1 1 5 3 8]
# [ 1.72887885  1.72887885  8.64439425  5.18663655 13.8310308 ]

# %%
newgame = pg.GameB(a_dic,{'la':1,'si':1,'wo':0.001,'a':7,'b':5,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/4039]
result = newgame.pd[1]/4039
for i in range(100): 
  newgame.run_slot()
  y.append(newgame.pd[1]/4039)
  result = np.vstack((result,newgame.pd[1]/4039))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s8=']=result
# Out:
# 0.3521832613095697
# [8 8 7 1 3]
# [6.72416167 6.72416167 5.88364146 0.84052021 2.52156063]

# %%
newgame = pg.GameB(a_dic,{'la':1.2,'si':0.7,'wo':0.001,'a':7,'b':5,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/4039]
result = newgame.pd[1]/4039
for i in range(100): 
  newgame.run_slot()
  y.append(newgame.pd[1]/4039)
  result = np.vstack((result,newgame.pd[1]/4039))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s8>']=result
# Out:
# -0.5419834989545649
# [8 7 2 4 7]
# [5.39892771 4.72406175 1.34973193 2.69946386 4.72406175]

# %%
newgame = pg.GameB(a_dic,{'la':0.7,'si':1.2,'wo':0.001,'a':7,'b':5,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/4039]
result = newgame.pd[1]/4039
for i in range(100): 
  newgame.run_slot()
  y.append(newgame.pd[1]/4039)
  result = np.vstack((result,newgame.pd[1]/4039))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s8<']=result
# Out:
# -2.440740445395832
# [1 5 5 8 5]
# [0.9922603  4.96130149 4.96130149 7.93808239 4.96130149]

# %%
newgame = pg.GameB(a_dic,{'la':1,'si':1,'wo':0.001,'a':7,'b':7,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/4039]
result = newgame.pd[1]/4039
for i in range(100): 
  newgame.run_slot()
  y.append(newgame.pd[1]/4039)
  result = np.vstack((result,newgame.pd[1]/4039))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s9=']=result
# Out:
# -11.302533850383568
# [1 3 1 7 5]
# [ 1.9835497   5.95064909  1.9835497  13.88484788  9.91774849]

# %%
newgame = pg.GameB(a_dic,{'la':1.2,'si':0.7,'wo':0.001,'a':7,'b':7,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/4039]
result = newgame.pd[1]/4039
for i in range(100): 
  newgame.run_slot()
  y.append(newgame.pd[1]/4039)
  result = np.vstack((result,newgame.pd[1]/4039))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s9>']=result
# Out:
# -1.3153241753073956
# [9 6 2 9 1]
# [8.14565863 5.43043908 1.81014636 8.14565863 0.90507318]

# %%
newgame = pg.GameB(a_dic,{'la':0.7,'si':1.2,'wo':0.001,'a':7,'b':7,'cn':5},[0.33,0.4,0.27],temp_fdic)
y=[newgame.pd[1]/4039]
result = newgame.pd[1]/4039
for i in range(100): 
  newgame.run_slot()
  y.append(newgame.pd[1]/4039)
  result = np.vstack((result,newgame.pd[1]/4039))
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())
print(newgame.payoff_platform())
print(newgame.company_strategies)
print(newgame.payoff_company())
results['s9<']=result
# Out:
# -10.887154775408334
# [4 2 9 2 2]
# [ 5.16996394  2.58498197 11.63241886  2.58498197  2.58498197]

# %%
if all (k in results for k in ('s1=','s1>','s1<','s2=','s2>','s2<','s3=','s3>','s3<','s4=','s4>','s4<','s5=','s5>','s5<','s6=','s6>','s6<','s7=','s7>','s7<','s8=','s8>','s8<','s9=','s9>','s9<')):
  print("ok")
# Out:
# ok

# %%
#save results
outfile = 'bresult_f.npz'
np.savez(outfile, **results)

# %%
npzfile = np.load(outfile)
print('npzfile.files: {}'.format(npzfile.files))
print('npzfile["s9>"]: {}'.format(npzfile["s9>"]))

# %%
np.random.dirichlet(np.ones(3),size=1)[0]*100
# Out:
# array([48.91954532, 46.39924343,  4.68121124])

# %%
import numpy as np
print('npzfile["std"]: {}'.format([0.29345928, 0.41725088, 0.28928984]))
npzfile = np.load('bresult_f.npz')
print('\n')
print('npzfile["s1="]: {}'.format(npzfile["s1="][-1]))
print('npzfile["s1>"]: {}'.format(npzfile["s1>"][-1]))
print('npzfile["s1<"]: {}'.format(npzfile["s1<"][-1]))
print('\n')
print('npzfile["s2="]: {}'.format(npzfile["s2="][-1]))
print('npzfile["s2>"]: {}'.format(npzfile["s2>"][-1]))
print('npzfile["s2<"]: {}'.format(npzfile["s2<"][-1]))
print('\n')
print('\n')
print('npzfile["s3="]: {}'.format(npzfile["s3="][-1]))
print('npzfile["s3>"]: {}'.format(npzfile["s3>"][-1]))
print('npzfile["s3<"]: {}'.format(npzfile["s3<"][-1]))
print('\n')
print('npzfile["s4="]: {}'.format(npzfile["s4="][-1]))
print('npzfile["s4>"]: {}'.format(npzfile["s4>"][-1]))
print('npzfile["s4<"]: {}'.format(npzfile["s4<"][-1]))
print('\n')
print('npzfile["s5="]: {}'.format(npzfile["s5="][-1]))
print('npzfile["s5>"]: {}'.format(npzfile["s5>"][-1]))
print('npzfile["s5<"]: {}'.format(npzfile["s5<"][-1]))
print('\n')
print('npzfile["s6="]: {}'.format(npzfile["s6="][-1]))
print('npzfile["s6>"]: {}'.format(npzfile["s6>"][-1]))
print('npzfile["s6<"]: {}'.format(npzfile["s6<"][-1]))
print('\n')
print('npzfile["s7="]: {}'.format(npzfile["s7="][-1]))
print('npzfile["s7>"]: {}'.format(npzfile["s7>"][-1]))
print('npzfile["s7<"]: {}'.format(npzfile["s7<"][-1]))
print('\n')
print('npzfile["s8="]: {}'.format(npzfile["s8="][-1]))
print('npzfile["s8>"]: {}'.format(npzfile["s8>"][-1]))
print('npzfile["s8<"]: {}'.format(npzfile["s8<"][-1]))
print('\n')
print('npzfile["s9="]: {}'.format(npzfile["s9="][-1]))
print('npzfile["s9>"]: {}'.format(npzfile["s9>"][-1]))
print('npzfile["s9<"]: {}'.format(npzfile["s9<"][-1]))

# %%
import numpy as np
print('npzfile["std"]: {}'.format([0.29345928, 0.41725088, 0.28928984]))
npzfile = np.load('bresult_f.npz')
print('\n')
print('npzfile["s1="]: {}'.format(npzfile["s1="][-1]))
print('npzfile["s2="]: {}'.format(npzfile["s2="][-1]))
print('npzfile["s3="]: {}'.format(npzfile["s3="][-1]))
print('npzfile["s4="]: {}'.format(npzfile["s4="][-1]))
print('npzfile["s5="]: {}'.format(npzfile["s5="][-1]))
print('npzfile["s6="]: {}'.format(npzfile["s6="][-1]))
print('npzfile["s7="]: {}'.format(npzfile["s7="][-1]))
print('npzfile["s8="]: {}'.format(npzfile["s8="][-1]))
print('npzfile["s9="]: {}'.format(npzfile["s9="][-1]))
print('\n')
print('npzfile["s1>"]: {}'.format(npzfile["s1>"][-1]))
print('npzfile["s2>"]: {}'.format(npzfile["s2>"][-1]))
print('npzfile["s3>"]: {}'.format(npzfile["s3>"][-1]))
print('npzfile["s4>"]: {}'.format(npzfile["s4>"][-1]))
print('npzfile["s5>"]: {}'.format(npzfile["s5>"][-1]))
print('npzfile["s6>"]: {}'.format(npzfile["s6>"][-1]))
print('npzfile["s7>"]: {}'.format(npzfile["s7>"][-1]))
print('npzfile["s8>"]: {}'.format(npzfile["s8>"][-1]))
print('npzfile["s9>"]: {}'.format(npzfile["s9>"][-1]))
print('\n')
print('npzfile["s1<"]: {}'.format(npzfile["s1<"][-1]))
print('npzfile["s2<"]: {}'.format(npzfile["s2<"][-1]))
print('npzfile["s3<"]: {}'.format(npzfile["s3<"][-1]))
print('npzfile["s4<"]: {}'.format(npzfile["s4<"][-1]))
print('npzfile["s5<"]: {}'.format(npzfile["s5<"][-1]))
print('npzfile["s6<"]: {}'.format(npzfile["s6<"][-1]))
print('npzfile["s7<"]: {}'.format(npzfile["s7<"][-1]))
print('npzfile["s8<"]: {}'.format(npzfile["s8<"][-1]))
print('npzfile["s9<"]: {}'.format(npzfile["s9<"][-1]))
# Out:
# npzfile["std"]: [0.29345928, 0.41725088, 0.28928984]
#
#
# npzfile["s1="]: [0.16365437 0.27531567 0.56102996]
# npzfile["s2="]: [0.00297103 0.00247586 0.99455311]
# npzfile["s3="]: [2.47586036e-03 9.90344145e-04 9.96533795e-01]
# npzfile["s4="]: [0.98687794 0.01114137 0.00198069]
# npzfile["s5="]: [0.31418668 0.34463976 0.34117356]
# npzfile["s6="]: [0.00222827 0.00866551 0.98910621]
# npzfile["s7="]: [0.99504828 0.00247586 0.00247586]
# npzfile["s8="]: [0.99083932 0.00668482 0.00247586]
# npzfile["s9="]: [0.3545432  0.32012874 0.32532805]
#
#
# npzfile["s1>"]: [0.48675415 0.23570191 0.27754395]
# npzfile["s2>"]: [0.00198069 0.00198069 0.99603862]
# npzfile["s3>"]: [0.00247586 0.0017331  0.99579104]
# npzfile["s4>"]: [0.99257242 0.00519931 0.00222827]
# npzfile["s5>"]: [0.54345135 0.09111166 0.36543699]
# npzfile["s6>"]: [0.00321862 0.00866551 0.98811587]
# npzfile["s7>"]: [9.98019312e-01 1.48551622e-03 4.95172072e-04]
# npzfile["s8>"]: [0.99727655 0.00123793 0.00148552]
# npzfile["s9>"]: [0.47140381 0.19881159 0.3297846 ]
#
#
# npzfile["s1<"]: [0.28472394 0.08615994 0.62911612]
# npzfile["s2<"]: [0.0034662  0.00420896 0.99232483]
# npzfile["s3<"]: [0.00222827 0.00495172 0.99282   ]
# npzfile["s4<"]: [0.99579104 0.00198069 0.00222827]
# npzfile["s5<"]: [0.25971775 0.22233226 0.51794999]
# npzfile["s6<"]: [0.0017331  0.00495172 0.99331518]
# npzfile["s7<"]: [0.99381035 0.00470413 0.00148552]
# npzfile["s8<"]: [0.98440208 0.00222827 0.01336965]
# npzfile["s9<"]: [0.10398614 0.21960881 0.67640505]

# %%
import numpy as np
outfile = 'bresult_f.npz'
npzfile = np.load(outfile)

# %%
import pandas as pd
writer = pd.ExcelWriter('c.xlsx')

# %%
dtr = pd.DataFrame(npzfile['s5>'])
dtr.to_excel(writer,'page_1',float_format='%.5f')
writer.save()

# %%
dtr = pd.DataFrame(npzfile['s5<'])
dtr.to_excel(writer,'page_2',float_format='%.5f')
writer.save()

# %%
writer.close()
