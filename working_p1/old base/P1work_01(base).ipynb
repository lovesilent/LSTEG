# %%
#connect my drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#go to the workplace
# %cd drive/MyDrive/Colab\ Notebooks
# %ls
# Out:
# /content/drive/MyDrive/Colab Notebooks
# DATA/  working_p1/

# %%
# find the dataset (i.e.,facebook)
# %cd DATA/EGO_FACEBOOK/
# Out:
# /content/drive/MyDrive/Colab Notebooks/DATA/EGO_FACEBOOK

# %%
#save dataset to dic
a_dic={}
with open('facebook_combined.txt', 'rt') as f:
  for line in f:
    key,value = line.split()
    if key not in a_dic:
      a_dic[key] = value
    else:
      a_dic[key] = a_dic[key]+' '+value
    if value not in a_dic:
      a_dic[value] = key
    else:
      a_dic[value] = a_dic[value]+' '+key

f.close()

# %%
print(a_dic)

# %%
# find the codes 
# %cd ../../working_p1/
# Out:
# /content/drive/My Drive/Colab Notebooks/working_p1

# %%
import p1game as pg
import numpy as np
import imp
import matplotlib.pylab as plt
from IPython import display

# %%
imp.reload(pg)

# %%
newgame = pg.GameS2(a_dic,{'la':1,'si':1,'wo':0.01},[0.3,0.4,0.3])
y=[newgame.pd[1]/4039]
for i in range(100): 
  newgame.run_slot(np.arange(1,1))
  y.append(newgame.pd[1]/4039)
  plt.plot(y,'o:')
  display.clear_output(wait=True)
  display.display(plt.gcf())

# %%
newgame = pg.GameS3(a_dic,{'la':2,'si':2,'wo':0.001,'G1':1,'G2':1,'G3':1},[0.4,0.4,0.2])
y=[newgame.pd[1]/4039]
for i in range(1000): 
  newgame.run_slot(500)
  y.append(newgame.pd[1]/4039)
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())

# %%
newgame = pg.GameS3(a_dic,{'la':2,'si':2,'wo':0.001,'G1':1,'G2':1,'G3':1},[0.4,0.4,0.2])
y=[newgame.pd[1]/4039]
for i in range(500): 
  newgame.run_slot(1000)
  y.append(newgame.pd[1]/4039)
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())

# %%
newgame = pg.GameS3(a_dic,{'la':1,'si':1,'wo':0.001,'G1':1,'G2':1,'G3':1},[0.38,0.35,0.27])
y=[newgame.pd[1]/4039]
for i in range(500): 
  newgame.run_slot(1000)
  y.append(newgame.pd[1]/4039)
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())

# %%
newgame = pg.GameS3(a_dic,{'la':1,'si':1,'wo':0.001,'G1':0.5,'G2':0.5,'G3':0.5},[0.38,0.35,0.27])
y=[newgame.pd[1]/4039]
for i in range(500): 
  newgame.run_slot(1000)
  y.append(newgame.pd[1]/4039)
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())

# %%
newgame = pg.GameS3(a_dic,{'la':1.2,'si':1.0,'wo':0.001,'G1':0.5,'G2':0.5,'G3':0.5},[0.38,0.35,0.27])
y=[newgame.pd[1]/4039]
for i in range(500): 
  newgame.run_slot(1000)
  y.append(newgame.pd[1]/4039)
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())

# %%
newgame = pg.GameS3(a_dic,{'la':2,'si':1,'wo':0.001,'G1':0.5,'G2':0.5,'G3':0.5},[0.38,0.35,0.27])
y=[newgame.pd[1]/4039]
for i in range(500): 
  newgame.run_slot(1000)
  y.append(newgame.pd[1]/4039)
  try:
    plt.plot(y,':')
    display.clear_output(wait=True)
    display.display(plt.gcf())
  except (TypeError,ValueError):
    print("Oops!")
    break
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# Oops!

# %%
newgame = pg.GameS3(a_dic,{'la':1.2,'si':0.8,'wo':0.001,'G1':0.5,'G2':0.5,'G3':0.5},[0.38,0.35,0.27])
y=[newgame.pd[1]/4039]
for i in range(500): 
  newgame.run_slot(1000)
  y.append(newgame.pd[1]/4039)
  try:
    plt.plot(y,':')
    display.clear_output(wait=True)
    display.display(plt.gcf())
  except (TypeError,ValueError):
    print("Oops!")
    break

# %%
newgame = pg.GameS3(a_dic,{'la':1,'si':2,'wo':0.001,'G1':0.5,'G2':0.5,'G3':0.5},[0.38,0.35,0.27])
y=[newgame.pd[1]/4039]
for i in range(500): 
  newgame.run_slot(1000)
  y.append(newgame.pd[1]/4039)
  try:
    plt.plot(y,':')
    display.clear_output(wait=True)
    display.display(plt.gcf())
  except (TypeError,ValueError):
    print("Oops!")
    break

# %%
newgame = pg.GameS3(a_dic,{'la':0.8,'si':1.2,'wo':0.001,'G1':0.5,'G2':0.5,'G3':0.5},[0.38,0.35,0.27])
y=[newgame.pd[1]/4039]
for i in range(500): 
  newgame.run_slot(1000)
  y.append(newgame.pd[1]/4039)
  try:
    plt.plot(y,':')
    display.clear_output(wait=True)
    display.display(plt.gcf())
  except (TypeError,ValueError):
    print("Oops!")
    break

# %%
newgame = pg.GameS3(a_dic,{'la':1,'si':1,'wo':0.001,'G1':0.6,'G2':0.5,'G3':0.4},[0.38,0.35,0.27])
y=[newgame.pd[1]/4039]
for i in range(500): 
  newgame.run_slot(1000)
  y.append(newgame.pd[1]/4039)
  try:
    plt.plot(y,':')
    display.clear_output(wait=True)
    display.display(plt.gcf())
  except (TypeError,ValueError):
    print("Oops!")
    break
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# Oops!

# %%
newgame = pg.GameS3(a_dic,{'la':1,'si':1,'wo':0.001,'G1':0.4,'G2':0.5,'G3':0.6},[0.38,0.35,0.27])
y=[newgame.pd[1]/4039]
for i in range(500): 
  newgame.run_slot(1000)
  y.append(newgame.pd[1]/4039)
  try:
    plt.plot(y,':')
    display.clear_output(wait=True)
    display.display(plt.gcf())
  except (TypeError,ValueError):
    print("Oops!")
    break
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# Oops!

# %%
newgame = pg.GameS3(a_dic,{'la':2,'si':1,'wo':0.001,'G1':0.4,'G2':0.5,'G3':0.6},[0.38,0.35,0.27])
y=[newgame.pd[1]/4039]
for i in range(500): 
  newgame.run_slot(1000)
  y.append(newgame.pd[1]/4039)
  try:
    plt.plot(y,':')
    display.clear_output(wait=True)
    display.display(plt.gcf())
  except (TypeError,ValueError):
    print("Oops!")
    break
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# Oops!

# %%
newgame = pg.GameS3(a_dic,{'la':1,'si':2,'wo':0.001,'G1':0.4,'G2':0.5,'G3':0.6},[0.38,0.35,0.27])
y=[newgame.pd[1]/4039]
for i in range(500): 
  newgame.run_slot(1000)
  y.append(newgame.pd[1]/4039)
  try:
    plt.plot(y,':')
    display.clear_output(wait=True)
    display.display(plt.gcf())
  except (TypeError,ValueError):
    print("Oops!")
    break
print(newgame.pd)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# Oops!
# (array([2, 3]), array([ 352, 3687]))

# %%
newgame = pg.GameS3(a_dic,{'la':2,'si':1,'wo':0.001,'G1':0.6,'G2':0.5,'G3':0.4},[0.38,0.35,0.27])
y=[newgame.pd[1]/4039]
for i in range(500): 
  try:
    newgame.run_slot(1000)
    y.append(newgame.pd[1]/4039)
    plt.plot(y,':')
    display.clear_output(wait=True)
    display.display(plt.gcf())
  except (TypeError,ValueError):
    print("Oops!")
    break
print(newgame.pd)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# Oops!
# (array([1, 3]), array([4030,    9]))

# %%
newgame = pg.GameS3(a_dic,{'la':1,'si':2,'wo':0.001,'G1':0.6,'G2':0.5,'G3':0.4},[0.38,0.35,0.27])
y=[newgame.pd[1]/4039]
for i in range(500): 
  try:
    newgame.run_slot(1000)
    y.append(newgame.pd[1]/4039)
    plt.plot(y,':')
    display.clear_output(wait=True)
    display.display(plt.gcf())
  except (TypeError,ValueError):
    print("Oops!")
    break
print(newgame.pd)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# Oops!
# (array([1, 3]), array([3853,  186]))
