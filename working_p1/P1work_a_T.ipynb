# %%
#connect my drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#go to the workplace
# %cd drive/MyDrive/Colab\ Notebooks
# %ls
# Out:
# /content/drive/MyDrive/Colab Notebooks
# DATA/  working_p1/

# %%
# find the dataset (i.e.,facebook)
# %cd DATA/EGO_TWITTER/
# Out:
# /content/drive/MyDrive/Colab Notebooks/DATA/EGO_TWITTER

# %%
#save dataset to dic
a_dic={}
with open('twitter_combined.txt', 'rt') as f:
  for line in f:
    key,value = line.split()
    if key not in a_dic:
      a_dic[key] = value
    else:
      a_dic[key] = a_dic[key]+' '+value
    if value not in a_dic:
      a_dic[value] = key
    else:
      a_dic[value] = a_dic[value]+' '+key

f.close()

# %%
print(a_dic)

# %%
# find the codes 
# %cd ../../working_p1/
# Out:
# /content/drive/My Drive/Colab Notebooks/working_p1

# %%
import p1game as pg
import numpy as np
import imp
import matplotlib.pylab as plt
from IPython import display

# %%
imp.reload(pg)
# Out:
# <module 'p1game' from '/content/drive/My Drive/Colab Notebooks/working_p1/p1game.py'>

# %%
newgame = pg.GameM(a_dic,{'la':2,'si':2,'wo':0.001,'G1':1,'G2':1,'G3':1},[0.4,0.4,0.2])
y=[newgame.pd[1]/81306]
for i in range(50): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())

# %%
newgame = pg.GameM(a_dic,{'la':2,'si':2,'wo':0.001,'G1':1,'G2':1,'G3':1},[0.38,0.35,0.27])
y=[newgame.pd[1]/81306]
for i in range(100): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())

# %%
newgame = pg.GameM(a_dic,{'la':1,'si':1,'wo':0.001,'G1':1,'G2':1,'G3':1},[0.38,0.35,0.27])
y=[newgame.pd[1]/81306]
for i in range(100): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())

# %%
newgame = pg.GameM(a_dic,{'la':1,'si':1,'wo':0.001,'G1':0.5,'G2':0.5,'G3':0.5},[0.38,0.35,0.27])
y=[newgame.pd[1]/81306]
for i in range(100): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())

# %%
newgame = pg.GameM(a_dic,{'la':1.2,'si':1.0,'wo':0.001,'G1':0.5,'G2':0.5,'G3':0.5},[0.38,0.35,0.27])
y=[newgame.pd[1]/81306]
for i in range(100): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  plt.plot(y,':')
  display.clear_output(wait=True)
  display.display(plt.gcf())

# %%
newgame = pg.GameM(a_dic,{'la':2,'si':1,'wo':0.001,'G1':0.5,'G2':0.5,'G3':0.5},[0.38,0.35,0.27])
y=[newgame.pd[1]/81306]
for i in range(100): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  try:
    plt.plot(y,':')
    display.clear_output(wait=True)
    display.display(plt.gcf())
  except (TypeError,ValueError):
    print("Oops!")
    break

# %%
newgame = pg.GameM(a_dic,{'la':1.2,'si':0.8,'wo':0.001,'G1':0.5,'G2':0.5,'G3':0.5},[0.38,0.35,0.27])
y=[newgame.pd[1]/81306]
for i in range(100): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  try:
    plt.plot(y,':')
    display.clear_output(wait=True)
    display.display(plt.gcf())
  except (TypeError,ValueError):
    print("Oops!")
    break

# %%
newgame = pg.GameM(a_dic,{'la':1,'si':2,'wo':0.001,'G1':0.5,'G2':0.5,'G3':0.5},[0.38,0.35,0.27])
y=[newgame.pd[1]/81306]
for i in range(100): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  try:
    plt.plot(y,':')
    display.clear_output(wait=True)
    display.display(plt.gcf())
  except (TypeError,ValueError):
    print("Oops!")
    break

# %%
newgame = pg.GameM(a_dic,{'la':0.8,'si':1.2,'wo':0.001,'G1':0.5,'G2':0.5,'G3':0.5},[0.38,0.35,0.27])
y=[newgame.pd[1]/81306]
for i in range(100): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  try:
    plt.plot(y,':')
    display.clear_output(wait=True)
    display.display(plt.gcf())
  except (TypeError,ValueError):
    print("Oops!")
    break

# %%
newgame = pg.GameM(a_dic,{'la':1,'si':1,'wo':0.001,'G1':0.6,'G2':0.5,'G3':0.4},[0.38,0.35,0.27])
y=[newgame.pd[1]/81306]
for i in range(100): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  try:
    plt.plot(y,':')
    display.clear_output(wait=True)
    display.display(plt.gcf())
  except (TypeError,ValueError):
    print("Oops!")
    break

# %%
newgame = pg.GameM(a_dic,{'la':1,'si':1,'wo':0.001,'G1':0.4,'G2':0.5,'G3':0.6},[0.38,0.35,0.27])
y=[newgame.pd[1]/81306]
for i in range(100): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  try:
    plt.plot(y,':')
    display.clear_output(wait=True)
    display.display(plt.gcf())
  except (TypeError,ValueError):
    print("Oops!")
    break

# %%
newgame = pg.GameM(a_dic,{'la':2,'si':1,'wo':0.001,'G1':0.4,'G2':0.5,'G3':0.6},[0.38,0.35,0.27])
y=[newgame.pd[1]/81306]
for i in range(100): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  try:
    plt.plot(y,':')
    display.clear_output(wait=True)
    display.display(plt.gcf())
  except (TypeError,ValueError):
    print("Oops!")
    break

# %%
newgame = pg.GameM(a_dic,{'la':1,'si':2,'wo':0.001,'G1':0.4,'G2':0.5,'G3':0.6},[0.38,0.35,0.27])
y=[newgame.pd[1]/81306]
for i in range(100): 
  newgame.run_slot()
  y.append(newgame.pd[1]/81306)
  try:
    plt.plot(y,':')
    display.clear_output(wait=True)
    display.display(plt.gcf())
  except (TypeError,ValueError):
    print("Oops!")
    break
print(newgame.pd)
# Out:
# (array([1, 2, 3]), array([  204,  9852, 71250]))

# %%
newgame = pg.GameM(a_dic,{'la':2,'si':1,'wo':0.001,'G1':0.6,'G2':0.5,'G3':0.4},[0.38,0.35,0.27])
y=[newgame.pd[1]/81306]
for i in range(100): 
  try:
    newgame.run_slot()
    y.append(newgame.pd[1]/81306)
    plt.plot(y,':')
    display.clear_output(wait=True)
    display.display(plt.gcf())
  except (TypeError,ValueError):
    print("Oops!")
    break
print(newgame.pd)
# Out:
# (array([1, 2, 3]), array([77393,   320,  3593]))

# %%
newgame = pg.GameM(a_dic,{'la':1,'si':2,'wo':0.001,'G1':0.6,'G2':0.5,'G3':0.4},[0.38,0.35,0.27])
y=[newgame.pd[1]/81306]
for i in range(100): 
  try:
    newgame.run_slot()
    y.append(newgame.pd[1]/81306)
    plt.plot(y,':')
    display.clear_output(wait=True)
    display.display(plt.gcf())
  except (TypeError,ValueError):
    print("Oops!")
    break
print(newgame.pd)
# Out:
# (array([1, 2, 3]), array([61893,  3172, 16241]))
