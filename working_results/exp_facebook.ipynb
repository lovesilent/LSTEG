# %%
#connect my drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#go to the workplace
# %cd drive/MyDrive/Colab\ Notebooks
# %ls
# Out:
# /content/drive/MyDrive/Colab Notebooks
# DATA/  tutorial/  working_p1/  working_p2/  working_results/

# %%
# find the dataset (i.e.,facebook)
# %cd DATA/EGO_FACEBOOK/
# Out:
# /content/drive/MyDrive/Colab Notebooks/DATA/EGO_FACEBOOK

# %%
#save dataset to dic
a_dic={}
with open('facebook_combined.txt', 'rt') as f:
  for line in f:
    key,value = line.split()
    if key not in a_dic:
      a_dic[key] = value
    else:
      a_dic[key] = a_dic[key]+' '+value
    if value not in a_dic:
      a_dic[value] = key
    else:
      a_dic[value] = a_dic[value]+' '+key

f.close()

# %%
print(a_dic)

# %%
# find the codes 
# %cd ../../working_results/
# Out:
# /content/drive/My Drive/Colab Notebooks/working_results

# %%
import exp as pg
import numpy as np
import imp
import matplotlib.pylab as plt
from IPython import display
from copy import deepcopy

# %%
imp.reload(pg)
# Out:
# <module 'exp' from '/content/drive/My Drive/Colab Notebooks/working_results/exp.py'>

# %%
results={}

# %%
newgame = pg.GameFinal(a_dic,{'la':1,'si':1,'wo':0.001,'a':5,'b':5,'cn':5},[0.33,0.4,0.27],None)
# Out:
# 4039

# %%
temp_fdic = deepcopy(newgame.fdic)

# %%
newgame = pg.GameFinal(a_dic,{'la':1,'si':1,'wo':0.001,'a':3,'b':3,'cn':5},[0.33,0.4,0.27],temp_fdic)
y, result = newgame.run_time(100)
plt.plot(y,':')
print(newgame.average_payoff_result())
print(newgame.random_payoff_result())
results['s1=']=result
# Out:
# 4039
# Loading...: 100%|██████████| 100/100 [01:23<00:00,  1.19it/s]
# {'ave_platform': 25.166412791317775, 'ave_company': array([2.78221261, 2.78221261, 2.78221261, 2.78221261, 2.78221261])}
# Loading...: 100%|██████████| 1000/1000 [00:00<00:00, 9497.61it/s]
# {'rnd_platform': 25.178412791324618, 'rnd_company': array([2.82864201, 2.74971243, 2.80345982, 2.73353287, 2.78371589])}

# %%
newgame = pg.GameFinal(a_dic,{'la':1.2,'si':0.7,'wo':0.001,'a':3,'b':3,'cn':5},[0.33,0.4,0.27],temp_fdic)
y, result = newgame.run_time(100)
plt.plot(y,':')
print(newgame.average_payoff_result())
print(newgame.random_payoff_result())
results['s1>']=result
# Out:
# 4039
# Loading...: 100%|██████████| 100/100 [01:23<00:00,  1.20it/s]
# {'ave_platform': 25.60972451892785, 'ave_company': array([3.26108062, 3.26108062, 3.26108062, 3.26108062, 3.26108062])}
# Loading...: 100%|██████████| 1000/1000 [00:00<00:00, 13041.95it/s]
# {'rnd_platform': 25.724724518952357, 'rnd_company': array([3.28544902, 3.22364505, 3.28792612, 3.25118884, 3.1421941 ])}

# %%
newgame = pg.GameFinal(a_dic,{'la':0.7,'si':1.2,'wo':0.001,'a':3,'b':3,'cn':5},[0.33,0.4,0.27],temp_fdic)
y, result = newgame.run_time(100)
plt.plot(y,':')
print(newgame.average_payoff_result())
print(newgame.random_payoff_result())
results['s1<']=result
# Out:
# 4039
# Loading...: 100%|██████████| 100/100 [01:22<00:00,  1.21it/s]
# {'ave_platform': 24.3154841226301, 'ave_company': array([2.15809922, 2.15809922, 2.15809922, 2.15809922, 2.15809922])}
# Loading...: 100%|██████████| 1000/1000 [00:00<00:00, 12450.81it/s]
# {'rnd_platform': 24.487484122663968, 'rnd_company': array([2.12300113, 2.08944107, 2.10620577, 2.17510654, 2.12474159])}

# %%
newgame = pg.GameFinal(a_dic,{'la':1,'si':1,'wo':0.001,'a':3,'b':5,'cn':5},[0.33,0.4,0.27],temp_fdic)
y, result = newgame.run_time(100)
plt.plot(y,':')
print(newgame.average_payoff_result())
print(newgame.random_payoff_result())
results['s2=']=result
# Out:
# 4039
# Loading...: 100%|██████████| 100/100 [01:22<00:00,  1.21it/s]
# {'ave_platform': 7.278192047202804, 'ave_company': array([-2.65154638, -2.65154638, -2.65154638, -2.65154638, -2.65154638])}
# Loading...: 100%|██████████| 1000/1000 [00:00<00:00, 12790.90it/s]
# {'rnd_platform': 7.406192047199814, 'rnd_company': array([-2.61370805, -2.71557954, -2.6871004 , -2.67831302, -2.69103087])}

# %%
newgame = pg.GameFinal(a_dic,{'la':1.2,'si':0.7,'wo':0.001,'a':3,'b':5,'cn':5},[0.33,0.4,0.27],temp_fdic)
y, result = newgame.run_time(100)
plt.plot(y,':')
print(newgame.average_payoff_result())
print(newgame.random_payoff_result())
results['s2>']=result
# Out:
# 4039
# Loading...: 100%|██████████| 100/100 [01:22<00:00,  1.21it/s]
# {'ave_platform': 8.80410943365147, 'ave_company': array([-2.09172392, -2.09172392, -2.09172392, -2.09172392, -2.09172392])}
# Loading...: 100%|██████████| 1000/1000 [00:00<00:00, 13137.00it/s]
# {'rnd_platform': 8.967109433644096, 'rnd_company': array([-2.13062108, -2.14840642, -2.1307547 , -2.11130918, -2.1005282 ])}

# %%
newgame = pg.GameFinal(a_dic,{'la':0.7,'si':1.2,'wo':0.001,'a':3,'b':5,'cn':5},[0.33,0.4,0.27],temp_fdic)
y, result = newgame.run_time(100)
plt.plot(y,':')
print(newgame.average_payoff_result())
print(newgame.random_payoff_result())
results['s2<']=result
# Out:
# 4039
# Loading...: 100%|██████████| 100/100 [01:22<00:00,  1.21it/s]
# {'ave_platform': 7.537934050390937, 'ave_company': array([-2.51779419, -2.51779419, -2.51779419, -2.51779419, -2.51779419])}
# Loading...: 100%|██████████| 1000/1000 [00:00<00:00,
}
# Loading...: 100%|██████████| 1000/1000 [00:00<00:00, 10379.68it/s]
# {'rnd_platform': -3.370726420249811, 'rnd_company': array([4.84534005, 4.76940514, 5.02656617, 4.83851617, 4.86919476])}

# %%
newgame = pg.GameFinal(a_dic,{'la':1.2,'si':0.7,'wo':0.001,'a':7,'b':7,'cn':5},[0.33,0.4,0.27],temp_fdic)
y, result = newgame.run_time(100)
plt.plot(y,':')
print(newgame.average_payoff_result())
print(newgame.random_payoff_result())
results['s9>']=result
# Out:
# 4039
# Loading...: 100%|██████████| 100/100 [01:25<00:00,  1.17it/s]
# {'ave_platform': -4.541051886804175, 'ave_company': array([3.93019203, 3.93019203, 3.93019203, 3.93019203, 3.93019203])}
# Loading...: 100%|██████████| 1000/1000 [00:00<00:00, 7883.22it/s]
# {'rnd_platform': -4.743051886809931, 'rnd_company': array([4.01966264, 3.93014149, 3.9245841 , 3.99303158, 3.98554033])}

# %%
newgame = pg.GameFinal(a_dic,{'la':0.7,'si':1.2,'wo':0.001,'a':7,'b':7,'cn':5},[0.33,0.4,0.27],temp_fdic)
y, result = newgame.run_time(100)
plt.plot(y,':')
print(newgame.average_payoff_result())
print(newgame.random_payoff_result())
results['s9<']=result
# Out:
# 4039
# Loading...: 100%|██████████| 100/100 [01:25<00:00,  1.17it/s]
# {'ave_platform': -4.447565951384755, 'ave_company': array([4.13119864, 4.13119864, 4.13119864, 4.13119864, 4.13119864])}
# Loading...: 100%|██████████| 1000/1000 [00:00<00:00, 11175.36it/s]
# {'rnd_platform': -4.331565951386901, 'rnd_company': array([4.21338837, 4.04840545, 4.11827048, 4.0894646 , 4.07046431])}

# %%
if all (k in results for k in ('s1=','s1>','s1<','s2=','s2>','s2<','s3=','s3>','s3<','s4=','s4>','s4<','s5=','s5>','s5<','s6=','s6>','s6<','s7=','s7>','s7<','s8=','s8>','s8<','s9=','s9>','s9<')):
  print("ok")
# Out:
# ok

# %%
#save results
outfile = 'result_f.npz'
np.savez(outfile, **results)

# %%
npzfile = np.load(outfile)
print('npzfile.files: {}'.format(npzfile.files))
print('npzfile["s9>"]: {}'.format(npzfile["s9>"]))
# Out:
# npzfile.files: ['s1=', 's1>', 's1<', 's2=', 's2>', 's2<', 's3=', 's3>', 's3<', 's4=', 's4>', 's4<', 's5=', 's5>', 's5<', 's6=', 's6>', 's6<', 's7=', 's7>', 's7<', 's8=', 's8>', 's8<', 's9=', 's9>', 's9<']
# npzfile["s9>"]: [[0.33176529 0.41099282 0.25724189]
#  [0.32953701 0.4307997  0.23966328]
#  [0.33027977 0.41693488 0.25278534]
#  [0.33349839 0.40307007 0.26343154]
#  [0.3421639  0.37335974 0.28447636]
#  [0.34538252 0.3599901  0.29462738]
#  [0.31814806 0.37781629 0.30403565]
#  [0.28497153 0.38202525 0.33300322]
#  [0.27977222 0.37831146 0.34191632]
#  [0.29933152 0.38598663 0.31468185]
#  [0.32706115 0.37534043 0.29759842]
#  [0.31517702 0.33795494 0.34686804]
#  [0.32508047 0.33448873 0.3404308 ]
#  [0.29388462 0.34414459 0.36197078]
#  [0.23743501 0.36444665 0.39811835]
#  [0.21193365 0.41718247 0.37088388]
#  [0.1950978  0.41965833 0.38524387]
#  [0.22777915 0.3864818  0.38573904]
#  [0.22183709 0.36939837 0.40876455]
#  [0.18420401 0.36048527 0.45531072]
# ...

# %%
np.random.dirichlet(np.ones(3),size=1)[0]*100
# Out:
# array([31.91284039, 42.64021341, 25.4469462 ])

# %%
import numpy as np
print('npzfile["std"]: {}'.format([0.29345928, 0.41725088, 0.28928984]))
npzfile = np.load('result_f.npz')
print('\n')
print('npzfile["s1="]: {}'.format(npzfile["s1="][-1]))
print('npzfile["s1>"]: {}'.format(npzfile["s1>"][-1]))
print('npzfile["s1<"]: {}'.format(npzfile["s1<"][-1]))
print('\n')
print('npzfile["s2="]: {}'.format(npzfile["s2="][-1]))
print('npzfile["s2>"]: {}'.format(npzfile["s2>"][-1]))
print('npzfile["s2<"]: {}'.format(npzfile["s2<"][-1]))
print('\n')
print('\n')
print('npzfile["s3="]: {}'.format(npzfile["s3="][-1]))
print('npzfile["s3>"]: {}'.format(npzfile["s3>"][-1]))
print('npzfile["s3<"]: {}'.format(npzfile["s3<"][-1]))
print('\n')
print('npzfile["s4="]: {}'.format(npzfile["s4="][-1]))
print('npzfile["s4>"]: {}'.format(npzfile["s4>"][-1]))
print('npzfile["s4<"]: {}'.format(npzfile["s4<"][-1]))
print('\n')
print('npzfile["s5="]: {}'.format(npzfile["s5="][-1]))
print('npzfile["s5>"]: {}'.format(npzfile["s5>"][-1]))
print('npzfile["s5<"]: {}'.format(npzfile["s5<"][-1]))
print('\n')
print('npzfile["s6="]: {}'.format(npzfile["s6="][-1]))
print('npzfile["s6>"]: {}'.format(npzfile["s6>"][-1]))
print('npzfile["s6<"]: {}'.format(npzfile["s6<"][-1]))
print('\n')
print('npzfile["s7="]: {}'.format(npzfile["s7="][-1]))
print('npzfile["s7>"]: {}'.format(npzfile["s7>"][-1]))
print('npzfile["s7<"]: {}'.format(npzfile["s7<"][-1]))
print('\n')
print('npzfile["s8="]: {}'.format(npzfile["s8="][-1]))
print('npzfile["s8>"]: {}'.format(npzfile["s8>"][-1]))
print('npzfile["s8<"]: {}'.format(npzfile["s8<"][-1]))
print('\n')
print('npzfile["s9="]: {}'.format(npzfile["s9="][-1]))
print('npzfile["s9>"]: {}'.format(npzfile["s9>"][-1]))
print('npzfile["s9<"]: {}'.format(npzfile["s9<"][-1]))
# Out:
# npzfile["std"]: [0.29345928, 0.41725088, 0.28928984]
#
#
# npzfile["s1="]: [0.21688537 0.43129487 0.35181976]
# npzfile["s1>"]: [0.45159693 0.25030948 0.29809359]
# npzfile["s1<"]: [0.10547165 0.41619213 0.47833622]
#
#
# npzfile["s2="]: [0.0017331  0.00321862 0.99504828]
# npzfile["s2>"]: [0.00222827 0.01163654 0.98613518]
# npzfile["s2<"]: [0.00198069 0.0034662  0.99455311]
#
#
#
#
# npzfile["s3="]: [2.22827433e-03 9.90344145e-04 9.96781382e-01]
# npzfile["s3>"]: [0.00321862 0.00247586 0.99430552]
# npzfile["s3<"]: [1.48551622e-03 9.90344145e-04 9.97524140e-01]
#
#
# npzfile["s4="]: [0.98885863 0.00965586 0.00148552]
# npzfile["s4>"]: [0.99579104 0.00297103 0.00123793]
# npzfile["s4<"]: [0.99603862 0.00272345 0.00123793]
#
#
# npzfile["s5="]: [0.31691013 0.23099777 0.4520921 ]
# npzfile["s5>"]: [0.29759842 0.30774944 0.39465214]
# npzfile["s5<"]: [0.24659569 0.31195841 0.4414459 ]
#
#
# npzfile["s6="]: [0.00470413 0.00272345 0.99257242]
# ...

# %%
import numpy as np
print('npzfile["std"]: {}'.format([0.29345928, 0.41725088, 0.28928984]))
npzfile = np.load('result_f.npz')
print('\n')
print('npzfile["s1="]: {}'.format(npzfile["s1="][-1]))
print('npzfile["s2="]: {}'.format(npzfile["s2="][-1]))
print('npzfile["s3="]: {}'.format(npzfile["s3="][-1]))
print('npzfile["s4="]: {}'.format(npzfile["s4="][-1]))
print('npzfile["s5="]: {}'.format(npzfile["s5="][-1]))
print('npzfile["s6="]: {}'.format(npzfile["s6="][-1]))
print('npzfile["s7="]: {}'.format(npzfile["s7="][-1]))
print('npzfile["s8="]: {}'.format(npzfile["s8="][-1]))
print('npzfile["s9="]: {}'.format(npzfile["s9="][-1]))
print('\n')
print('npzfile["s1>"]: {}'.format(npzfile["s1>"][-1]))
print('npzfile["s2>"]: {}'.format(npzfile["s2>"][-1]))
print('npzfile["s3>"]: {}'.format(npzfile["s3>"][-1]))
print('npzfile["s4>"]: {}'.format(npzfile["s4>"][-1]))
print('npzfile["s5>"]: {}'.format(npzfile["s5>"][-1]))
print('npzfile["s6>"]: {}'.format(npzfile["s6>"][-1]))
print('npzfile["s7>"]: {}'.format(npzfile["s7>"][-1]))
print('npzfile["s8>"]: {}'.format(npzfile["s8>"][-1]))
print('npzfile["s9>"]: {}'.format(npzfile["s9>"][-1]))
print('\n')
print('npzfile["s1<"]: {}'.format(npzfile["s1<"][-1]))
print('npzfile["s2<"]: {}'.format(npzfile["s2<"][-1]))
print('npzfile["s3<"]: {}'.format(npzfile["s3<"][-1]))
print('npzfile["s4<"]: {}'.format(npzfile["s4<"][-1]))
print('npzfile["s5<"]: {}'.format(npzfile["s5<"][-1]))
print('npzfile["s6<"]: {}'.format(npzfile["s6<"][-1]))
print('npzfile["s7<"]: {}'.format(npzfile["s7<"][-1]))
print('npzfile["s8<"]: {}'.format(npzfile["s8<"][-1]))
print('npzfile["s9<"]: {}'.format(npzfile["s9<"][-1]))
# Out:
# npzfile["std"]: [0.29345928, 0.41725088, 0.28928984]
#
#
# npzfile["s1="]: [0.21688537 0.43129487 0.35181976]
# npzfile["s2="]: [0.0017331  0.00321862 0.99504828]
# npzfile["s3="]: [2.22827433e-03 9.90344145e-04 9.96781382e-01]
# npzfile["s4="]: [0.98885863 0.00965586 0.00148552]
# npzfile["s5="]: [0.31691013 0.23099777 0.4520921 ]
# npzfile["s6="]: [0.00470413 0.00272345 0.99257242]
# npzfile["s7="]: [9.94553107e-01 4.70413469e-03 7.42758108e-04]
# npzfile["s8="]: [9.97524140e-01 2.22827433e-03 2.47586036e-04]
# npzfile["s9="]: [0.27977222 0.32235702 0.39787076]
#
#
# npzfile["s1>"]: [0.45159693 0.25030948 0.29809359]
# npzfile["s2>"]: [0.00222827 0.01163654 0.98613518]
# npzfile["s3>"]: [0.00321862 0.00247586 0.99430552]
# npzfile["s4>"]: [0.99579104 0.00297103 0.00123793]
# npzfile["s5>"]: [0.29759842 0.30774944 0.39465214]
# npzfile["s6>"]: [0.00148552 0.00123793 0.99727655]
# npzfile["s7>"]: [9.96286209e-01 2.72344640e-03 9.90344145e-04]
# ...

# %% [markdown]
# ---------------------------------------------------------

# %%
newresults={}

# %%
newgame = pg.GameFinal(a_dic,{'la':1,'si':1,'wo':0.001,'a':9,'b':9,'cn':5},[0.33,0.4,0.27],temp_fdic)
y, result = newgame.run_time(100)
plt.plot(y,':')
print(newgame.average_payoff_result())
print(newgame.random_payoff_result())
newresults['s99=']=result
# Out:
# 4039
# Loading...: 100%|██████████| 100/100 [01:34<00:00,  1.06it/s]
# {'ave_platform': -20.07025920118456, 'ave_company': array([3.54176469, 3.54176469, 3.54176469, 3.54176469, 3.54176469])}
# Loading...: 100%|██████████| 1000/1000 [00:00<00:00, 11303.03it/s]
# {'rnd_platform': -20.254259201170782, 'rnd_company': array([3.60872826, 3.40969092, 3.59888897, 3.60277321, 3.67274209])}

# %%
newgame = pg.GameFinal(a_dic,{'la':1.2,'si':0.7,'wo':0.001,'a':9,'b':9,'cn':5},[0.33,0.4,0.27],temp_fdic)
y, result = newgame.run_time(100)
plt.plot(y,':')
print(newgame.average_payoff_result())
print(newgame.random_payoff_result())
newresults['s99>']=result
# Out:
# 4039
# Loading...: 100%|██████████| 100/100 [01:31<00:00,  1.09it/s]
# {'ave_platform': -17.730876587704728, 'ave_company': array([5.99750749, 5.99750749, 5.99750749, 5.99750749, 5.99750749])}
# Loading...: 100%|██████████| 1000/1000 [00:00<00:00, 11327.35it/s]
# {'rnd_platform': -17.50587658772921, 'rnd_company': array([5.9055934 , 5.83140613, 6.11251962, 5.96602623, 5.94699208])}

# %%
newgame = pg.GameFinal(a_dic,{'la':0.7,'si':1.2,'wo':0.001,'a':9,'b':9,'cn':5},[0.33,0.4,0.27],temp_fdic)
y, result = newgame.run_time(100)
plt.plot(y,':')
print(newgame.average_payoff_result())
print(newgame.random_payoff_result())
newresults['s99<']=result
# Out:
# 4039
# Loading...: 100%|██████████| 100/100 [01:36<00:00,  1.04it/s]
# {'ave_platform': -21.701201571993085, 'ave_company': array([2.2689643, 2.2689643, 2.2689643, 2.2689643, 2.2689643])}
# Loading...: 100%|██████████| 1000/1000 [00:00<00:00, 11458.38it/s]
# {'rnd_platform': -21.684201571978793, 'rnd_company': array([2.30954703, 2.28682733, 2.24979633, 2.21914789, 2.26250292])}

# %%
newgame = pg.GameFinal(a_dic,{'la':1,'si':1,'wo':0.001,'a':7,'b':9,'cn':5},[0.33,0.4,0.27],temp_fdic)
y, result = newgame.run_time(100)
plt.plot(y,':')
print(newgame.average_payoff_result())
print(newgame.random_payoff_result())
newresults['s79=']=result
# Out:
# 4039
# Loading...: 100%|██████████| 100/100 [01:36<00:00,  1.03it/s]
# {'ave_platform': -17.264526636598628, 'ave_company': array([0.32573218, 0.32573218, 0.32573218, 0.32573218, 0.32573218])}
# Loading...: 100%|██████████| 1000/1000 [00:00<00:00, 11170.63it/s]
# {'rnd_platform': -17.00852663662909, 'rnd_company': array([0.27472206, 0.28978289, 0.27506906, 0.25596854, 0.27711834])}

# %%
newgame = pg.GameFinal(a_dic,{'la':1.2,'si':0.7,'wo':0.001,'a':7,'b':9,'cn':5},[0.33,0.4,0.27],temp_fdic)
y, result = newgame.run_time(100)
plt.plot(y,':')
print(newgame.average_payoff_result())
print(newgame.random_payoff_result())
newresults['s79>']=result
# Out:
# 4039
# Loading...: 100%|██████████| 100/100 [01:37<00:00,  1.02it/s]
# {'ave_platform': -17.333789167668034, 'ave_company': array([0.07518039, 0.07518039, 0.07518039, 0.07518039, 0.07518039])}
# Loading...: 100%|██████████| 1000/1000 [00:00<00:00, 9792.55it/s]
# {'rnd_platform': -17.497789167643557, 'rnd_company': array([0.08388893, 0.12927599, 0.09742367, 0.11100197, 0.11831138])}

# %%
newgame = pg.GameFinal(a_dic,{'la':0.7,'si':1.2,'wo':0.001,'a':7,'b':9,'cn':5},[0.33,0.4,0.27],temp_fdic)
y, result = newgame.run_time(100)
plt.plot(y,':')
print(newgame.average_payoff_result())
print(newgame.random_payoff_result())
newresults['s79<']=result
# Out:
# 4039
# Loading...: 100%|██████████| 100/100 [01:37<00:00,  1.02it/s]
# {'ave_platform': -18.08630173628161, 'ave_company': array([0.57275757, 0.57275757, 0.57275757, 0.57275757, 0.57275757])}
# Loading...: 100%|██████████| 1000/1000 [00:00<00:00, 11712.60it/s]
# {'rnd_platform': -18.1873017362665, 'rnd_company': array([0.60547446, 0.58448404, 0.56359283, 0.5296677 , 0.68156882])}

# %%
newgame = pg.GameFinal(a_dic,{'la':1,'si':1,'wo':0.001,'a':9,'b':7,'cn':5},[0.33,0.4,0.27],temp_fdic)
y, result = newgame.run_time(100)
plt.plot(y,':')
print(newgame.average_payoff_result())
print(newgame.random_payoff_result())
newresults['s97=']=result
# Out:
# 4039
# Loading...: 100%|██████████| 100/100 [01:30<00:00,  1.10it/s]
# {'ave_platform': -16.159993521266006, 'ave_company': array([4.98342605, 4.98342605, 4.98342605, 4.98342605, 4.98342605])}
# Loading...: 100%|██████████| 1000/1000 [00:00<00:00, 11413.07it/s]
# {'rnd_platform': -16.167993521256154, 'rnd_company': array([5.0573582 , 4.7689901 , 4.96317156, 5.20236517, 4.93324522])}

# %%
newgame = pg.GameFinal(a_dic,{'la':1.2,'si':0.7,'wo':0.001,'a':9,'b':7,'cn':5},[0.33,0.4,0.27],temp_fdic)
y, result = newgame.run_time(100)
plt.plot(y,':')
print(newgame.average_payoff_result())
print(newgame.random_payoff_result())
newresults['s97>']=result
# Out:
# 4039
# Loading...: 100%|██████████| 100/100 [01:30<00:00,  1.10it/s]
# {'ave_platform': -14.056208217043993, 'ave_company': array([6.19399119, 6.19399119, 6.19399119, 6.19399119, 6.19399119])}
# Loading...: 100%|██████████| 1000/1000 [00:00<00:00, 11668.51it/s]
# {'rnd_platform': -14.405208217027727, 'rnd_company': array([6.29913895, 6.15031489, 6.46786112, 6.16674226, 6.23489872])}

# %%
newgame = pg.GameFinal(a_dic,{'la':0.7,'si':1.2,'wo':0.001,'a':9,'b':7,'cn':5},[0.33,0.4,0.27],temp_fdic)
y, result = newgame.run_time(100)
plt.plot(y,':')
print(newgame.average_payoff_result())
print(newgame.random_payoff_result())
newresults['s97<']=result
# Out:
# 4039
# Loading...: 100%|██████████| 100/100 [01:29<00:00,  1.12it/s]
# {'ave_platform': -15.093082390259863, 'ave_company': array([6.22200589, 6.22200589, 6.22200589, 6.22200589, 6.22200589])}
# Loading...: 100%|██████████| 1000/1000 [00:00<00:00, 10451.43it/s]
# {'rnd_platform': -15.160082390256433, 'rnd_company': array([6.09397687, 6.2545928 , 6.24489322, 6.2996248 , 6.28394176])}

# %%
newgame = pg.GameFinal(a_dic,{'la':1,'si':1,'wo':0.001,'a
=result
# Out:
# 4039
# Loading...: 100%|██████████| 100/100 [01:28<00:00,  1.13it/s]
# {'ave_platform': 3.467808315950158, 'ave_company': array([4.5970056, 4.5970056, 4.5970056, 4.5970056, 4.5970056])}
# Loading...: 100%|██████████| 1000/1000 [00:00<00:00, 7222.14it/s]
# {'rnd_platform': 3.941808315952308, 'rnd_company': array([4.55358929, 4.41140124, 4.35627122, 4.61831915, 4.57144707])}

# %%
newgame = pg.GameFinal(a_dic,{'la':1.2,'si':0.7,'wo':0.001,'a':9,'b':2,'cn':5},[0.33,0.4,0.27],temp_fdic)
y, result = newgame.run_time(100)
plt.plot(y,':')
print(newgame.average_payoff_result())
print(newgame.random_payoff_result())
newresults['s92>']=result
# Out:
# 4039
# Loading...: 100%|██████████| 100/100 [01:32<00:00,  1.08it/s]
# {'ave_platform': -0.2690372575200092, 'ave_company': array([4.99949074, 4.99949074, 4.99949074, 4.99949074, 4.99949074])}
# Loading...: 100%|██████████| 1000/1000 [00:00<00:00, 9531.21it/s]
# {'rnd_platform': -0.6030372575225094, 'rnd_company': array([5.15476053, 5.04152111, 5.04045274, 5.13459254, 4.9601268 ])}

# %%
newgame = pg.GameFinal(a_dic,{'la':0.7,'si':1.2,'wo':0.001,'a':9,'b':2,'cn':5},[0.33,0.4,0.27],temp_fdic)
y, result = newgame.run_time(100)
plt.plot(y,':')
print(newgame.average_payoff_result())
print(newgame.random_payoff_result())
newresults['s92<']=result
# Out:
# 4039
# Loading...: 100%|██████████| 100/100 [01:30<00:00,  1.11it/s]
# {'ave_platform': 1.1190906258213242, 'ave_company': array([5.3447923, 5.3447923, 5.3447923, 5.3447923, 5.3447923])}
# Loading...: 100%|██████████| 1000/1000 [00:00<00:00, 11597.56it/s]
# {'rnd_platform': 1.0090906258220043, 'rnd_company': array([5.37675292, 5.32760014, 5.40298218, 5.44939346, 5.27723281])}

# %%
if all (k in results for k in ('s1=','s1>','s1<','s2=','s2>','s2<','s3=','s3>','s3<','s4=','s4>','s4<','s5=','s5>','s5<','s6=','s6>','s6<','s7=','s7>','s7<','s8=','s8>','s8<','s9=','s9>','s9<')):
  print("ok")
# Out:
# ok

# %%
if all (k in newresults for k in ('s99=','s99>','s99<','s97=','s97>','s97<','s79=','s79>','s79<','s95=','s95>','s95<','s59=','s59>','s59<','s19=','s29>','s18<','s82=','s92>','s92<')):
  print("ok")
# Out:
# ok

# %%
#save old results
outfile = 'old_result_f.npz'
np.savez(outfile, **results)

# %%
#save new results
outfile = 'new_result_f.npz'
np.savez(outfile, **newresults)

# %%
npzfile = np.load('old_result_f.npz')

# %%
import pandas as pd
writer = pd.ExcelWriter('ff.xlsx')

# %%
dtr = pd.DataFrame(npzfile['s2='])
dtr.to_excel(writer,'s2=',float_format='%.5f')
writer.save()

# %%
dtr = pd.DataFrame(npzfile['s2>'])
dtr.to_excel(writer,'s2>',float_format='%.5f')
writer.save()

# %%
dtr = pd.DataFrame(npzfile['s2<'])
dtr.to_excel(writer,'s2<',float_format='%.5f')
writer.save()

# %%
dtr = pd.DataFrame(npzfile['s8='])
dtr.to_excel(writer,'s8=',float_format='%.5f')
writer.save()

# %%
dtr = pd.DataFrame(npzfile['s8>'])
dtr.to_excel(writer,'s8>',float_format='%.5f')
writer.save()

# %%
dtr = pd.DataFrame(npzfile['s8<'])
dtr.to_excel(writer,'s8<',float_format='%.5f')
writer.save()

# %%
writer.close()
